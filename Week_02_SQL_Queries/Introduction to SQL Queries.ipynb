# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction-to-SQL-Queries" data-toc-modified-id="Introduction-to-SQL-Queries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction to SQL Queries</a></span></li><li><span><a href="#Objectives" data-toc-modified-id="Objectives-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#Motivation" data-toc-modified-id="Motivation-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Motivation</a></span></li><li><span><a href="#Relational-Databases" data-toc-modified-id="Relational-Databases-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Relational Databases</a></span><ul class="toc-item"><li><span><a href="#Database-Schema" data-toc-modified-id="Database-Schema-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Database Schema</a></span></li><li><span><a href="#Columns" data-toc-modified-id="Columns-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Columns</a></span></li><li><span><a href="#Keys" data-toc-modified-id="Keys-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Keys</a></span></li></ul></li><li><span><a href="#SQLite" data-toc-modified-id="SQLite-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>SQLite</a></span><ul class="toc-item"><li><span><a href="#Sidebar:-More-About-SQLite" data-toc-modified-id="Sidebar:-More-About-SQLite-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><em>Sidebar: More About SQLite</em></a></span></li><li><span><a href="#Load-a-SQLite-DB" data-toc-modified-id="Load-a-SQLite-DB-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Load a SQLite DB</a></span></li><li><span><a href="#Query-the-airports-Table" data-toc-modified-id="Query-the-airports-Table-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Query the <code>airports</code> Table</a></span></li><li><span><a href="#pd.read_sql()" data-toc-modified-id="pd.read_sql()-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span><code>pd.read_sql()</code></a></span></li><li><span><a href="#Explore-the-Schema" data-toc-modified-id="Explore-the-Schema-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Explore the Schema</a></span></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Exercise</a></span></li></ul></li><li><span><a href="#Writing-SQL-Queries" data-toc-modified-id="Writing-SQL-Queries-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Writing SQL Queries</a></span><ul class="toc-item"><li><span><a href="#SELECT-Statement" data-toc-modified-id="SELECT-Statement-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>SELECT Statement</a></span></li><li><span><a href="#SELECT:-Picking-Columns" data-toc-modified-id="SELECT:-Picking-Columns-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>SELECT: Picking Columns</a></span><ul class="toc-item"><li><span><a href="#DISTINCT" data-toc-modified-id="DISTINCT-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span><code>DISTINCT</code></a></span></li><li><span><a href="#AS" data-toc-modified-id="AS-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span><code>AS</code></a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Functions</a></span><ul class="toc-item"><li><span><a href="#Aggregation" data-toc-modified-id="Aggregation-6.2.3.1"><span class="toc-item-num">6.2.3.1&nbsp;&nbsp;</span>Aggregation</a></span></li><li><span><a href="#Datatype-Compatibility" data-toc-modified-id="Datatype-Compatibility-6.2.3.2"><span class="toc-item-num">6.2.3.2&nbsp;&nbsp;</span>Datatype Compatibility</a></span></li><li><span><a href="#CAST()" data-toc-modified-id="CAST()-6.2.3.3"><span class="toc-item-num">6.2.3.3&nbsp;&nbsp;</span><code>CAST()</code></a></span></li></ul></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Exercise</a></span></li></ul></li><li><span><a href="#FROM:-Picking-Tables" data-toc-modified-id="FROM:-Picking-Tables-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>FROM: Picking Tables</a></span></li><li><span><a href="#WHERE:-Picking-Rows" data-toc-modified-id="WHERE:-Picking-Rows-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>WHERE: Picking Rows</a></span><ul class="toc-item"><li><span><a href="#IS" data-toc-modified-id="IS-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span><code>IS</code></a></span></li></ul></li><li><span><a href="#ORDER-BY:-Sorting-Results" data-toc-modified-id="ORDER-BY:-Sorting-Results-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>ORDER BY: Sorting Results</a></span></li><li><span><a href="#LIMIT:-Number-of-Results" data-toc-modified-id="LIMIT:-Number-of-Results-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>LIMIT: Number of Results</a></span></li></ul></li><li><span><a href="#Exercises" data-toc-modified-id="Exercises-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Exercises</a></span><ul class="toc-item"><li><span><a href="#Country-List" data-toc-modified-id="Country-List-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Country List</a></span></li><li><span><a href="#Southern-Airports" data-toc-modified-id="Southern-Airports-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Southern Airports</a></span></li><li><span><a href="#Active-UK-Airlines" data-toc-modified-id="Active-UK-Airlines-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Active UK Airlines</a></span></li><li><span><a href="#Explore-Routes" data-toc-modified-id="Explore-Routes-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Explore Routes</a></span></li></ul></li><li><span><a href="#Level-Up:-CASE" data-toc-modified-id="Level-Up:-CASE-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Level Up: <code>CASE</code></a></span></li><li><span><a href="#Level-Up:-SQL-Joins" data-toc-modified-id="Level-Up:-SQL-Joins-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Level Up: SQL Joins</a></span></li></ul></div>

# %% [markdown]
# # Introduction to SQL Queries
#
# ![sql](img/sql-logo.jpg)

# %% [markdown]
# # Objectives

# %% [markdown]
# - Describe relational databases
# - Connect to a SQLite database and get schema information
# - Use SQL SELECT and `pd.read_sql()` to query databases
# - Use WHERE, ORDER BY, and LIMIT to modify queries

# %% [markdown]
# # Motivation

# %% [markdown]
# Most data aren't stored in static files like CSVs or JSONs. Rather, data are typically stored in **databases** that make it easy for many users to store, update, share, and access data in real time. CSVs and JSONs are just extracts of some data from those databases.
#
# **Structured Query Language (SQL)** is a common language for interacting with databases, and will be invaluable for you in almost any data role. You will use it often to get the data that you need for your analyses.

# %% [markdown]
# # Relational Databases

# %% [markdown]
# **Relational databases** typically have multiple **tables** containing data, and the tables have defined relationships.

# %% [markdown]
# ![rdb](img/relational-dbms-model.png)
# [reference for image ](https://www.studytonight.com/dbms/database-model.php)

# %% [markdown]
# ## Database Schema

# %% [markdown]
# Each database has a **schema** that defines the structure of the database, including the tables and relationships between tables.

# %% [markdown]
# ![schema](img/MySQL_Schema_Music_Example.png)
#
# [source of image](https://database.guide/what-is-a-database-schema/)

# %% [markdown]
# ##  Columns

# %% [markdown]
# Similar to how DataFrames can have multiple Series, tables can have multiple **columns** (aka "fields"). Each column has a datatype, but the datatypes available for SQL table columns differ from the datatypes in `pandas`.

# %% [markdown]
# ![table example](img/columns.png)

# %% [markdown]
# ## Keys

# %% [markdown]
# A **primary key** uniquely identifies each row in a table. This is often a unique ID number.
# A **foreign key** is used in one table to refer to the primary key from another table.

# %% [markdown]
# We **join** tables using these keys to get data from multiple tables at once - we will cover this in a future lesson on SQL Joins.

# %% [markdown]
# ![rdb](img/relational-dbms-model.png)
# [reference for image ](https://www.studytonight.com/dbms/database-model.php)

# %% [markdown]
# # SQLite

# %% [markdown]
# ![sqlite](img/SQLite-Python.jpg)

# %% [markdown]
# SQLite is one of many tools that exist to create databases. We use it here because it is easy to integrate into a Jupyter Notebook using the `sqlite3` package.
#
# There are many other database tools out there, and they all work somewhat differently with their own SQL dialects. Just know that the specific methods or syntax you see here will differ slightly in other database implementations.

# %% [markdown]
# ## _Sidebar: More About SQLite_

# %% [markdown]
# "SQLite is a C library that provides a lightweight disk-based database that doesn’t require a separate server process and allows accessing the database using a nonstandard variant of the SQL query language. Some applications can use SQLite for internal data storage. It’s also possible to prototype an application using SQLite and then port the code to a larger database such as PostgreSQL or Oracle." - [sqlite documentation](https://docs.python.org/2/library/sqlite3.html)

# %% [markdown]
# ## Load a SQLite DB

# %% [markdown]
# Import the `sqlite3` package, which will allow us to load a SQLite database.

# %%
import sqlite3

# %% [markdown]
# In this repository is a `flights.db` file that we can open as a SQLite database. This database contains tables with information about airlines, airports, and flight routes.

# %%
# !ls
# Out:
# Introduction to SQL Queries - Jupyter Notebook.pdf
# Introduction to SQL Queries.ipynb
# Lab_Assignment
# SQL Aggregation and Join - Jupyter Notebook.pdf
# SQL Aggregation and Join.ipynb
# SQL_Subqueries.ipynb
# SQL_Subqueries.pdf
# data
# img

# %% [markdown]
# First, we'll use the `sqlite3` package to create a connection to the database, which is currently just stored in that file on our hard drive.

# %%
con = sqlite3.connect('data/flights.db')

# %% [markdown]
# Next, we'll create a cursor to interact with the database. Like the cursor for your mouse interacts with pixels on your screen, this cursor will allow us to interact with the elements of the database.

# %%
cursor = con.cursor()

# %% [markdown]
# ## Query the `airports` Table

# %% [markdown]
# We will write a simple query using the SQL SELECT statement, which returns data from the database. We write the query as a string, which will then get parsed via the `sqlite3` package.
#
# In this case, we say `SELECT *` to specify that we want data from all columns, and we say `FROM airports` to specify that we want data from the `airports` table.

# %%
airports_query = \
"""
SELECT * 
FROM airports
"""

# %% [markdown]
# To run this query, we use the `.execute()` method with our cursor.

# %%
cursor.execute(airports_query)

# %% [markdown]
# Note that the `.execute()` method didn't actually return our data. The data is now just available in our cursor object. We'll use the `.fetchall()` method to get all the rows from our query.

# %%
cursor.fetchall()
# Out:
# [(0,
#   '1',
#   'Goroka',
#   'Goroka',
#   'Papua New Guinea',
#   'GKA',
#   'AYGA',
#   '-6.081689',
#   '145.391881',
#   '5282',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (1,
#   '2',
#   'Madang',
#   'Madang',
#   'Papua New Guinea',
#   'MAG',
#   'AYMD',
#   '-5.207083',
#   '145.7887',
#   '20',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (2,
#   '3',
#   'Mount Hagen',
#   'Mount Hagen',
#   'Papua New Guinea',
#   'HGU',
#   'AYMH',
#   '-5.826789',
#   '144.295861',
#   '5388',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (3,
#   '4',
#   'Nadzab',
#   'Nadzab',
#   'Papua New Guinea',
#   'LAE',
#   'AYNZ',
#   '-6.569828',
#   '146.726242',
#   '239',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (4,
#   '5',
#   'Port Moresby Jacksons Intl',
#   'Port Moresby',
#   'Papua New Guinea',
#   'POM',
#   'AYPY',
#   '-9.443383',
#   '147.22005',
#   '146',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (5,
#   '6',
#   'Wewak Intl',
#   'Wewak',
#   'Papua New Guinea',
#   'WWK',
#   'AYWK',
#   '-3.583828',
#   '143.669186',
#   '19',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (6,
#   '7',
#   'Narsarsuaq',
#   'Narssarssuaq',
#   'Greenland',
#   'UAK',
#   'BGBW',
#   '61.160517',
#   '-45.425978',
#   '112',
#   '-3',
#   'E',
#   'America/Godthab'),
#  (7,
#   '8',
#   'Nuuk',
#   'Godthaab',
#   'Greenland',
#   'GOH',
#   'BGGH',
#   '64.190922',
#   '-51.678064',
#   '283',
#   '-3',
#   'E',
#   'America/Godthab'),
#  (8,
#   '9',
#   'Sondre Stromfjord',
#   'Sondrestrom',
#   'Greenland',
#   'SFJ',
#   'BGSF',
#   '67.016969',
#   '-50.689325',
#   '165',
#   '-3',
#   'E',
#   'America/Godthab'),
#  (9,
#   '10',
#   'Thule Air Base',
#   'Thule',
#   'Greenland',
#   'THU',
#   'BGTL',
#   '76.531203',
#   '-68.703161',
#   '251',
#   '-4',
#   'E',
#   'America/Thule'),
#  (10,
#   '11',
#   'Akureyri',
#   'Akureyri',
#   'Iceland',
#   'AEY',
#   'BIAR',
#   '65.659994',
#   '-18.072703',
#   '6',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (11,
#   '12',
#   'Egilsstadir',
#   'Egilsstadir',
#   'Iceland',
#   'EGS',
#   'BIEG',
#   '65.283333',
#   '-14.401389',
#   '76',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (12,
#   '13',
#   'Hornafjordur',
#   'Hofn',
#   'Iceland',
#   'HFN',
#   'BIHN',
#   '64.295556',
#   '-15.227222',
#   '24',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (13,
#   '14',
#   'Husavik',
#   'Husavik',
#   'Iceland',
#   'HZK',
#   'BIHU',
#   '65.952328',
#   '-17.425978',
#   '48',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (14,
#   '15',
#   'Isafjordur',
#   'Isafjordur',
#   'Iceland',
#   'IFJ',
#   'BIIS',
#   '66.058056',
#   '-23.135278',
#   '8',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (15,
#   '16',
#   'Keflavik International Airport',
#   'Keflavik',
#   'Iceland',
#   'KEF',
#   'BIKF',
#   '63.985',
#   '-22.605556',
#   '171',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (16,
#   '17',
#   'Patreksfjordur',
#   'Patreksfjordur',
#   'Iceland',
#   'PFJ',
#   'BIPA',
#   '65.555833',
#   '-23.965',
#   '11',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (17,
#   '18',
#   'Reykjavik',
#   'Reykjavik',
#   'Iceland',
#   'RKV',
#   'BIRK',
#   '64.13',
#   '-21.940556',
#   '48',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (18,
#   '19',
#   'Siglufjordur',
#   'Siglufjordur',
#   'Iceland',
#   'SIJ',
#   'BISI',
#   '66.133333',
#   '-18.916667',
#   '10',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (19,
#   '20',
#   'Vestmannaeyjar',
#   'Vestmannaeyjar',
#   'Iceland',
#   'VEY',
#   'BIVM',
#   '63.424303',
#   '-20.278875',
#   '326',
#   '0',
#   'N',
#   'Atlantic/Reykjavik'),
#  (20,
#   '21',
#   'Sault Ste Marie',
#   'Sault Sainte Marie',
#   'Canada',
#   'YAM',
#   'CYAM',
#   '46.485001',
#   '-84.509445',
#   '630',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (21,
#   '22',
#   'Winnipeg St Andrews',
#   'Winnipeg',
#   'Canada',
#   'YAV',
#   'CYAV',
#   '50.056389',
#   '-97.0325',
#   '760',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (22,
#   '23',
#   'Shearwater',
#   'Halifax',
#   'Canada',
#   'YAW',
#   'CYAW',
#   '44.639721',
#   '-63.499444',
#   '167',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (23,
#   '24',
#   'St Anthony',
#   'St. Anthony',
#   'Canada',
#   'YAY',
#   'CYAY',
#   '51.391944',
#   '-56.083056',
#   '108',
#   '-3.5',
#   'A',
#   'America/St_Johns'),
#  (24,
#   '25',
#   'Tofino',
#   'Tofino',
#   'Canada',
#   'YAZ',
#   'CYAZ',
#   '49.082222',
#   '-125.7725',
#   '80',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (25,
#   '26',
#   'Kugaaruk',
#   'Pelly Bay',
#   'Canada',
#   'YBB',
#   'CYBB',
#   '68.534444',
#   '-89.808056',
#   '56',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (26,
#   '27',
#   'Baie Comeau',
#   'Baie Comeau',
#   'Canada',
#   'YBC',
#   'CYBC',
#   '49.1325',
#   '-68.204444',
#   '71',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (27,
#   '28',
#   'Bagotville',
#   'Bagotville',
#   'Canada',
#   'YBG',
#   'CYBG',
#   '48.330555',
#   '-70.996391',
#   '522',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (28,
#   '29',
#   'Baker Lake',
#   'Baker Lake',
#   'Canada',
#   'YBK',
#   'CYBK',
#   '64.298889',
#   '-96.077778',
#   '59',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (29,
#   '30',
#   'Campbell River',
#   'Campbell River',
#   'Canada',
#   'YBL',
#   'CYBL',
#   '49.950832',
#   '-125.270833',
#   '346',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (30,
#   '31',
#   'Brandon Muni',
#   'Brandon',
#   'Canada',
#   'YBR',
#   'CYBR',
#   '49.91',
#   '-99.951944',
#   '1343',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (31,
#   '32',
#   'Cambridge Bay',
#   'Cambridge Bay',
#   'Canada',
#   'YCB',
#   'CYCB',
#   '69.108055',
#   '-105.138333',
#   '90',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (32,
#   '33',
#   'Nanaimo',
#   'Nanaimo',
#   'Canada',
#   'YCD',
#   'CYCD',
#   '49.052333',
#   '-123.870167',
#   '93',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (33,
#   '34',
#   'Castlegar',
#   'Castlegar',
#   'Canada',
#   'YCG',
#   'CYCG',
#   '49.296389',
#   '-117.6325',
#   '1624',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (34,
#   '35',
#   'Miramichi',
#   'Chatham',
#   'Canada',
#   'YCH',
#   'CYCH',
#   '47.007778',
#   '-65.449167',
#   '108',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (35,
#   '36',
#   'Charlo',
#   'Charlo',
#   'Canada',
#   'YCL',
#   'CYCL',
#   '47.990833',
#   '-66.330278',
#   '132',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (36,
#   '37',
#   'Kugluktuk',
#   'Coppermine',
#   'Canada',
#   'YCO',
#   'CYCO',
#   '67.816667',
#   '-115.143889',
#   '74',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (37,
#   '38',
#   'Coronation',
#   'Coronation',
#   'Canada',
#   'YCT',
#   'CYCT',
#   '52.075001',
#   '-111.445278',
#   '2595',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (38,
#   '39',
#   'Chilliwack',
#   'Chilliwack',
#   'Canada',
#   'YCW',
#   'CYCW',
#   '49.152779',
#   '-121.93889',
#   '32',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (39,
#   '40',
#   'Clyde River',
#   'Clyde River',
#   'Canada',
#   'YCY',
#   'CYCY',
#   '70.486111',
#   '-68.516667',
#   '87',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (40,
#   '41',
#   'Fairmont Hot Springs',
#   'Coral Harbour',
#   'Canada',
#   'YZS',
#   'CYCZ',
#   '64.193333',
#   '-83.359444',
#   '2661',
#   '-5',
#   'A',
#   'America/Coral_Harbour'),
#  (41,
#   '42',
#   'Dawson City',
#   'Dawson',
#   'Canada',
#   'YDA',
#   'CYDA',
#   '64.043056',
#   '-139.127778',
#   '1215',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (42,
#   '43',
#   'Burwash',
#   'Burwash',
#   'Canada',
#   'YDB',
#   'CYDB',
#   '61.371111',
#   '-139.040556',
#   '2647',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (43,
#   '44',
#   'Princeton',
#   'Princeton',
#   'Canada',
#   'YDC',
#   'CYDC',
#   '49.468056',
#   '-120.511389',
#   '2298',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (44,
#   '45',
#   'Deer Lake',
#   'Deer Lake',
#   'Canada',
#   'YDF',
#   'CYDF',
#   '49.210833',
#   '-57.391388',
#   '72',
#   '-3.5',
#   'A',
#   'America/St_Johns'),
#  (45,
#   '46',
#   'Dease Lake',
#   'Dease Lake',
#   'Canada',
#   'YDL',
#   'CYDL',
#   '58.422222',
#   '-130.032222',
#   '2600',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (46,
#   '47',
#   'Dauphin Barker',
#   'Dauphin',
#   'Canada',
#   'YDN',
#   'CYDN',
#   '51.100834',
#   '-100.0525',
#   '999',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (47,
#   '48',
#   'Dawson Creek',
#   'Dawson Creek',
#   'Canada',
#   'YDQ',
#   'CYDQ',
#   '55.742333',
#   '-120.183',
#   '2148',
#   '-7',
#   'A',
#   'America/Dawson_Creek'),
#  (48,
#   '49',
#   'Edmonton Intl',
#   'Edmonton',
#   'Canada',
#   'YEG',
#   'CYEG',
#   '53.309723',
#   '-113.579722',
#   '2373',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (49,
#   '50',
#   'Arviat',
#   'Eskimo Point',
#   'Canada',
#   'YEK',
#   'CYEK',
#   '61.094166',
#   '-94.070833',
#   '32',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (50,
#   '51',
#   'Estevan',
#   'Estevan',
#   'Canada',
#   'YEN',
#   'CYEN',
#   '49.210278',
#   '-102.965833',
#   '1905',
#   '-6',
#   'N',
#   'America/Regina'),
#  (51,
#   '52',
#   'Edson',
#   'Edson',
#   'Canada',
#   'YET',
#   'CYET',
#   '53.578888',
#   '-116.465',
#   '3041',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (52,
#   '53',
#   'Eureka',
#   'Eureka',
#   'Canada',
#   'YEU',
#   'CYEU',
#   '79.994722',
#   '-85.814167',
#   '256',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (53,
#   '54',
#   'Inuvik Mike Zubko',
#   'Inuvik',
#   'Canada',
#   'YEV',
#   'CYEV',
#   '68.304167',
#   '-133.482778',
#   '224',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (54,
#   '55',
#   'Iqaluit',
#   'Iqaluit',
#   'Canada',
#   'YFB',
#   'CYFB',
#   '63.75639',
#   '-68.555832',
#   '110',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (55,
#   '56',
#   'Fredericton',
#   'Fredericton',
#   'Canada',
#   'YFC',
#   'CYFC',
#   '45.868889',
#   '-66.537222',
#   '68',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (56,
#   '57',
#   'Forestville',
#   'Forestville',
#   'Canada',
#   None,
#   'CYFE',
#   '48.746111',
#   '-69.097222',
#   '293',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (57,
#   '58',
#   'Flin Flon',
#   'Flin Flon',
#   'Canada',
#   'YFO',
#   'CYFO',
#   '54.678055',
#   '-101.681667',
#   '997',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (58,
#   '59',
#   'Fort Resolution',
#   'Fort Resolution',
#   'Canada',
#   'YFR',
#   'CYFR',
#   '61.180832',
#   '-113.689722',
#   '526',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (59,
#   '60',
#   'Fort Simpson',
#   'Fort Simpson',
#   'Canada',
#   'YFS',
#   'CYFS',
#   '61.760153',
#   '-121.236525',
#   '555',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (60,
#   '61',
#   'Kingston',
#   'Kingston',
#   'Canada',
#   'YGK',
#   'CYGK',
#   '44.225277',
#   '-76.596944',
#   '305',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (61,
#   '62',
#   'La Grande Riviere',
#   'La Grande Riviere',
#   'Canada',
#   'YGL',
#   'CYGL',
#   '53.625278',
#   '-77.704167',
#   '639',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (62,
#   '63',
#   'Gaspe',
#   'Gaspe',
#   'Canada',
#   'YGP',
#   'CYGP',
#   '48.775278',
#   '-64.478611',
#   '108',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (63,
#   '64',
#   'Geraldton Greenstone Regional',
#   'Geraldton',
#   'Canada',
#   'YGQ',
#   'CYGQ',
#   '49.778332',
#   '-86.939445',
#   '1144',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (64,
#   '65',
#   'Iles De La Madeleine',
#   'Iles De La Madeleine',
#   'Canada',
#   'YGR',
#   'CYGR',
#   '47.424721',
#   '-61.778056',
#   '35',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (65,
#   '66',
#   'Hudson Bay',
#   'Hudson Bay',
#   'Canada',
#   'YHB',
#   'CYHB',
#   '52.816666',
#   '-102.31139',
#   '1175',
#   '-6',
#   'N',
#   'America/Regina'),
#  (66,
#   '67',
#   'Dryden Rgnl',
#   'Dryden',
#   'Canada',
#   'YHD',
#   'CYHD',
#   '49.831667',
#   '-92.744167',
#   '1354',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (67,
#   '68',
#   'Ulukhaktok Holman',
#   'Holman Island',
#   'Canada',
#   'YHI',
#   'CYHI',
#   '70.762778',
#   '-117.806111',
#   '117',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (68,
#   '69',
#   'Gjoa Haven',
#   'Gjoa Haven',
#   'Canada',
#   'YHK',
#   'CYHK',
#   '68.635556',
#   '-95.849722',
#   '152',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (69,
#   '70',
#   'Hamilton',
#   'Hamilton',
#   'Canada',
#   'YHM',
#   'CYHM',
#   '43.173611',
#   '-79.935',
#   '780',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (70,
#   '71',
#   'St Hubert',
#   'Montreal',
#   'Canada',
#   'YHU',
#   'CYHU',
#   '45.5175',
#   '-73.416944',
#   '90',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (71,
#   '72',
#   'Hay River',
#   'Hay River',
#   'Canada',
#   'YHY',
#   'CYHY',
#   '60.839722',
#   '-115.782778',
#   '543',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (72,
#   '73',
#   'Halifax Intl',
#   'Halifax',
#   'Canada',
#   'YHZ',
#   'CYHZ',
#   '44.880833',
#   '-63.50861',
#   '477',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (73,
#   '74',
#   'Atikokan Muni',
#   'Atikokan',
#   'Canada',
#   'YIB',
#   'CYIB',
#   '48.773888',
#   '-91.638611',
#   '1408',
#   '-5',
#   'A',
#   'America/Coral_Harbour'),
#  (74,
#   '75',
#   'Pond Inlet',
#   'Pond Inlet',
#   'Canada',
#   'YIO',
#   'CYIO',
#   '72.683334',
#   '-77.966667',
#   '181',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (75,
#   '76',
#   'St Jean',
#   'St. Jean',
#   'Canada',
#   'YJN',
#   'CYJN',
#   '45.294445',
#   '-73.281111',
#   '136',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (76,
#   '77',
#   'Stephenville',
#   'Stephenville',
#   'Canada',
#   'YJT',
#   'CYJT',
#   '48.544167',
#   '-58.549999',
#   '80',
#   '-3.5',
#   'A',
#   'America/St_Johns'),
#  (77,
#   '78',
#   'Kamloops',
#   'Kamloops',
#   'Canada',
#   'YKA',
#   'CYKA',
#   '50.702222',
#   '-120.444444',
#   '1133',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (78,
#   '79',
#   'Waterloo',
#   'Waterloo',
#   'Canada',
#   'YKF',
#   'CYKF',
#   '43.460833',
#   '-80.378611',
#   '1054',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (79,
#   '80',
#   'Schefferville',
#   'Schefferville',
#   'Canada',
#   'YKL',
#   'CYKL',
#   '54.805278',
#   '-66.805278',
#   '1709',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (80,
#   '81',
#   'Kindersley',
#   'Kindersley',
#   'Canada',
#   'YKY',
#   'CYKY',
#   '51.5175',
#   '-109.180833',
#   '2277',
#   '-6',
#   'N',
#   'America/Regina'),
#  (81,
#   '82',
#   'Buttonville Muni',
#   'Toronto',
#   'Canada',
#   'YKZ',
#   'CYKZ',
#   '43.862221',
#   '-79.37',
#   '650',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (82,
#   '83',
#   'Chapleau',
#   'Chapleau',
#   'Canada',
#   'YLD',
#   'CYLD',
#   '47.82',
#   '-83.346667',
#   '1470',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (83,
#   '84',
#   'Meadow Lake',
#   'Meadow Lake',
#   'Canada',
#   'YLJ',
#   'CYLJ',
#   '54.125278',
#   '-108.522778',
#   '1576',
#   '-6',
#   'N',
#   'America/Regina'),
#  (84,
#   '85',
#   'Lloydminster',
#   'Lloydminster',
#   'Canada',
#   'YLL',
#   'CYLL',
#   '53.309166',
#   '-110.0725',
#   '2193',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (85,
#   '86',
#   'Alert',
#   'Alert',
#   'Canada',
#   'YLT',
#   'CYLT',
#   '82.517778',
#   '-62.280556',
#   '100',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (86,
#   '87',
#   'Kelowna',
#   'Kelowna',
#   'Canada',
#   'YLW',
#   'CYLW',
#   '49.956112',
#   '-119.377778',
#   '1409',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (87,
#   '88',
#   'Mayo',
#   'Mayo',
#   'Canada',
#   'YMA',
#   'CYMA',
#   '63.616389',
#   '-135.868333',
#   '1653',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (88,
#   '89',
#   'Moose Jaw Air Vice Marshal C M Mcewen',
#   'Moose Jaw',
#   'Canada',
#   'YMJ',
#   'CYMJ',
#   '50.330278',
#   '-105.559167',
#   '1892',
#   '-6',
#   'N',
#   'America/Regina'),
#  (89,
#   '90',
#   'Fort Mcmurray',
#   'Fort Mcmurray',
#   'Canada',
#   'YMM',
#   'CYMM',
#   '56.653333',
#   '-111.221944',
#   '1211',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (90,
#   '91',
#   'Moosonee',
#   'Moosonee',
#   'Canada',
#   'YMO',
#   'CYMO',
#   '51.291111',
#   '-80.607778',
#   '30',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (91,
#   '92',
#   'Maniwaki',
#   'Maniwaki',
#   'Canada',
#   'YMW',
#   'CYMW',
#   '46.272778',
#   '-75.990556',
#   '656',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (92,
#   '93',
#   'Montreal Intl Mirabel',
#   'Montreal',
#   'Canada',
#   'YMX',
#   'CYMX',
#   '45.681944',
#   '-74.005278',
#   '270',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (93,
#   '94',
#   'Natashquan',
#   'Natashquan',
#   'Canada',
#   'YNA',
#   'CYNA',
#   '50.19',
#   '-61.789167',
#   '39',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (94,
#   '95',
#   'Gatineau',
#   'Gatineau',
#   'Canada',
#   'YND',
#   'CYND',
#   '45.521694',
#   '-75.563589',
#   '211',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (95,
#   '96',
#   'Matagami',
#   'Matagami',
#   'Canada',
#   'YNM',
#   'CYNM',
#   '49.761667',
#   '-77.802778',
#   '918',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (96,
#   '97',
#   'Old Crow',
#   'Old Crow',
#   'Canada',
#   'YOC',
#   'CYOC',
#   '67.570556',
#   '-139.839167',
#   '824',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (97,
#   '98',
#   'Cold Lake',
#   'Cold Lake',
#   'Canada',
#   'YOD',
#   'CYOD',
#   '54.404999',
#   '-110.279444',
#   '1775',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (98,
#   '99',
#   'High Level',
#   'High Level',
#   'Canada',
#   'YOJ',
#   'CYOJ',
#   '58.621389',
#   '-117.164722',
#   '1110',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (99,
#   '100',
#   'Ottawa Macdonald Cartier Intl',
#   'Ottawa',
#   'Canada',
#   'YOW',
#   'CYOW',
#   '45.3225',
#   '-75.669167',
#   '374',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (100,
#   '101',
#   'Prince Albert Glass Field',
#   'Prince Albert',
#   'Canada',
#   'YPA',
#   'CYPA',
#   '53.214167',
#   '-105.672778',
#   '1405',
#   '-6',
#   'N',
#   'America/Regina'),
#  (101,
#   '102',
#   'Peace River',
#   'Peace River',
#   'Canada',
#   'YPE',
#   'CYPE',
#   '56.226944',
#   '-117.447222',
#   '1873',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (102,
#   '103',
#   'Southport',
#   'Portage-la-prairie',
#   'Canada',
#   'YPG',
#   'CYPG',
#   '49.903056',
#   '-98.273889',
#   '885',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (103,
#   '104',
#   'Pitt Meadows',
#   'Pitt Meadows',
#   'Canada',
#   None,
#   'CYPK',
#   '49.21611',
#   '-122.71',
#   '11',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (104,
#   '105',
#   'Pickle Lake',
#   'Pickle Lake',
#   'Canada',
#   'YPL',
#   'CYPL',
#   '51.446388',
#   '-90.214167',
#   '1267',
#   '-5',
#   'A',
#   'America/Coral_Harbour'),
#  (105,
#   '106',
#   'Port Menier',
#   'Port Menier',
#   'Canada',
#   'YPN',
#   'CYPN',
#   '49.836389',
#   '-64.288611',
#   '167',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (106,
#   '107',
#   'Peterborough',
#   'Peterborough',
#   'Canada',
#   'YPQ',
#   'CYPQ',
#   '44.23',
#   '-78.363333',
#   '628',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (107,
#   '108',
#   'Prince Rupert',
#   'Prince Pupert',
#   'Canada',
#   'YPR',
#   'CYPR',
#   '54.28611',
#   '-130.444722',
#   '116',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (108,
#   '109',
#   'Fort Chipewyan',
#   'Fort Chipewyan',
#   'Canada',
#   'YPY',
#   'CYPY',
#   '58.767223',
#   '-111.117222',
#   '761',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (109,
#   '110',
#   'Muskoka',
#   'Muskoka',
#   'Canada',
#   'YQA',
#   'CYQA',
#   '44.974722',
#   '-79.303333',
#   '925',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (110,
#   '111',
#   'Quebec Jean Lesage Intl',
#   'Quebec',
#   'Canada',
#   'YQB',
#   'CYQB',
#   '46.791111',
#   '-71.393333',
#   '244',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (111,
#   '112',
#   'Red Deer Regional',
#   'Red Deer Industrial',
#   'Canada',
#   'YQF',
#   'CYQF',
#   '52.182222',
#   '-113.894444',
#   '2968',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (112,
#   '113',
#   'Windsor',
#   'Windsor',
#   'Canada',
#   'YQG',
#   'CYQG',
#   '42.275556',
#   '-82.955556',
#   '622',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (113,
#   '114',
#   'Watson Lake',
#   'Watson Lake',
#   'Canada',
#   'YQH',
#   'CYQH',
#   '60.116389',
#   '-128.8225',
#   '2255',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (114,
#   '115',
#   'Kenora',
#   'Kenora',
#   'Canada',
#   'YQK',
#   'CYQK',
#   '49.788334',
#   '-94.363056',
#   '1332',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (115,
#   '116',
#   'Lethbridge',
#   'Lethbridge',
#   'Canada',
#   'YQL',
#   'CYQL',
#   '49.630278',
#   '-112.799722',
#   '3047',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (116,
#   '117',
#   'Greater Moncton Intl',
#   'Moncton',
#   'Canada',
#   'YQM',
#   'CYQM',
#   '46.112221',
#   '-64.678611',
#   '232',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (117,
#   '119',
#   'Comox',
#   'Comox',
#   'Canada',
#   'YQQ',
#   'CYQQ',
#   '49.710833',
#   '-124.886667',
#   '84',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (118,
#   '120',
#   'Regina Intl',
#   'Regina',
#   'Canada',
#   'YQR',
#   'CYQR',
#   '50.431944',
#   '-104.665833',
#   '1894',
#   '-6',
#   'N',
#   'America/Regina'),
#  (119,
#   '121',
#   'Thunder Bay',
#   'Thunder Bay',
#   'Canada',
#   'YQT',
#   'CYQT',
#   '48.371944',
#   '-89.323889',
#   '653',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (120,
#   '122',
#   'Grande Prairie',
#   'Grande Prairie',
#   'Canada',
#   'YQU',
#   'CYQU',
#   '55.179722',
#   '-118.885',
#   '2195',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (121,
#   '123',
#   'Yorkton Muni',
#   'Yorkton',
#   'Canada',
#   'YQV',
#   'CYQV',
#   '51.264721',
#   '-102.461667',
#   '1635',
#   '-6',
#   'N',
#   'America/Regina'),
#  (122,
#   '124',
#   'North Battleford',
#   'North Battleford',
#   'Canada',
#   'YQW',
#   'CYQW',
#   '52.769167',
#   '-108.24361',
#   '1799',
#   '-6',
#   'N',
#   'America/Regina'),
#  (123,
#   '125',
#   'Gander Intl',
#   'Gander',
#   'Canada',
#   'YQX',
#   'CYQX',
#   '48.936944',
#   '-54.568056',
#   '496',
#   '-3.5',
#   'A',
#   'America/St_Johns'),
#  (124,
#   '126',
#   'Sydney',
#   'Sydney',
#   'Canada',
#   'YQY',
#   'CYQY',
#   '46.161388',
#   '-60.047779',
#   '203',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (125,
#   '127',
#   'Quesnel',
#   'Quesnel',
#   'Canada',
#   'YQZ',
#   'CYQZ',
#   '53.026112',
#   '-122.510278',
#   '1789',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (126,
#   '128',
#   'Resolute Bay',
#   'Resolute',
#   'Canada',
#   'YRB',
#   'CYRB',
#   '74.716944',
#   '-94.969444',
#   '215',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (127,
#   '129',
#   'Riviere Du Loup',
#   'Riviere Du Loup',
#   'Canada',
#   'YRI',
#   'CYRI',
#   '47.764444',
#   '-69.584722',
#   '427',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (128,
#   '130',
#   'Roberval',
#   'Roberval',
#   'Canada',
#   'YRJ',
#   'CYRJ',
#   '48.52',
#   '-72.265556',
#   '586',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (129,
#   '131',
#   'Rocky Mountain House',
#   'Rocky Mountain House',
#   'Canada',
#   'YRM',
#   'CYRM',
#   '52.429722',
#   '-114.904167',
#   '3244',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (130,
#   '132',
#   'Rankin Inlet',
#   'Rankin Inlet',
#   'Canada',
#   'YRT',
#   'CYRT',
#   '62.81139',
#   '-92.115833',
#   '94',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (131,
#   '133',
#   'Sudbury',
#   'Sudbury',
#   'Canada',
#   'YSB',
#   'CYSB',
#   '46.625',
#   '-80.798889',
#   '1141',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (132,
#   '134',
#   'Sherbrooke',
#   'Sherbrooke',
#   'Canada',
#   'YSC',
#   'CYSC',
#   '45.438611',
#   '-71.691389',
#   '792',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (133,
#   '135',
#   'Saint John',
#   'St. John',
#   'Canada',
#   'YSJ',
#   'CYSJ',
#   '45.316111',
#   '-65.890278',
#   '357',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (134,
#   '136',
#   'Fort Smith',
#   'Fort Smith',
#   'Canada',
#   'YSM',
#   'CYSM',
#   '60.020278',
#   '-111.961944',
#   '671',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (135,
#   '137',
#   'Nanisivik',
#   'Nanisivik',
#   'Canada',
#   'YSR',
#   'CYSR',
#   '72.982222',
#   '-84.613611',
#   '2106',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (136,
#   '138',
#   'Summerside',
#   'Summerside',
#   'Canada',
#   'YSU',
#   'CYSU',
#   '46.440556',
#   '-63.833611',
#   '56',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (137,
#   '139',
#   'Sachs Harbour',
#   'Sachs Harbour',
#   'Canada',
#   'YSY',
#   'CYSY',
#   '71.993889',
#   '-125.2425',
#   '282',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (138,
#   '140',
#   'Cape Dorset',
#   'Cape Dorset',
#   'Canada',
#   'YTE',
#   'CYTE',
#   '64.23',
#   '-76.526667',
#   '164',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (139,
#   '141',
#   'Thompson',
#   'Thompson',
#   'Canada',
#   'YTH',
#   'CYTH',
#   '55.801111',
#   '-97.864166',
#   '729',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (140,
#   '142',
#   'Trenton',
#   'Trenton',
#   'Canada',
#   'YTR',
#   'CYTR',
#   '44.118889',
#   '-77.528056',
#   '283',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (141,
#   '143',
#   'Timmins',
#   'Timmins',
#   'Canada',
#   'YTS',
#   'CYTS',
#   '48.569721',
#   '-81.376667',
#   '967',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (142,
#   '144',
#   'City Centre',
#   'Toronto',
#   'Canada',
#   'YTZ',
#   'CYTZ',
#   '43.627499',
#   '-79.396167',
#   '251',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (143,
#   '145',
#   'Tuktoyaktuk',
#   'Tuktoyaktuk',
#   'Canada',
#   'YUB',
#   'CYUB',
#   '69.433334',
#   '-133.026389',
#   '15',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (144,
#   '146',
#   'Pierre Elliott Trudeau Intl',
#   'Montreal',
#   'Canada',
#   'YUL',
#   'CYUL',
#   '45.470556',
#   '-73.740833',
#   '118',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (145,
#   '147',
#   'Repulse Bay',
#   'Repulse Bay',
#   'Canada',
#   'YUT',
#   'CYUT',
#   '66.521389',
#   '-86.224722',
#   '80',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (146,
#   '148',
#   'Hall Beach',
#   'Hall Beach',
#   'Canada',
#   'YUX',
#   'CYUX',
#   '68.776111',
#   '-81.243611',
#   '27',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (147,
#   '149',
#   'Rouyn Noranda',
#   'Rouyn',
#   'Canada',
#   'YUY',
#   'CYUY',
#   '48.206111',
#   '-78.835556',
#   '988',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (148,
#   '150',
#   'La Ronge',
#   'La Ronge',
#   'Canada',
#   'YVC',
#   'CYVC',
#   '55.15139',
#   '-105.261944',
#   '1242',
#   '-6',
#   'N',
#   'America/Regina'),
#  (149,
#   '151',
#   'Vermilion',
#   'Vermillion',
#   'Canada',
#   'YVG',
#   'CYVG',
#   '53.355833',
#   '-110.82389',
#   '2025',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (150,
#   '152',
#   'Qikiqtarjuaq',
#   'Broughton Island',
#   'Canada',
#   'YVM',
#   'CYVM',
#   '67.545833',
#   '-64.031389',
#   '21',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (151,
#   '153',
#   'Val D Or',
#   "Val D'or",
#   'Canada',
#   'YVO',
#   'CYVO',
#   '48.053333',
#   '-77.782778',
#   '1107',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (152,
#   '154',
#   'Kuujjuaq',
#   'Quujjuaq',
#   'Canada',
#   'YVP',
#   'CYVP',
#   '58.096111',
#   '-68.426944',
#   '129',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (153,
#   '155',
#   'Norman Wells',
#   'Norman Wells',
#   'Canada',
#   'YVQ',
#   'CYVQ',
#   '65.281617',
#   '-126.798219',
#   '238',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (154,
#   '156',
#   'Vancouver Intl',
#   'Vancouver',
#   'Canada',
#   'YVR',
#   'CYVR',
#   '49.193889',
#   '-123.184444',
#   '14',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (155,
#   '157',
#   'Buffalo Narrows',
#   'Buffalo Narrows',
#   'Canada',
#   'YVT',
#   'CYVT',
#   '55.841944',
#   '-108.4175',
#   '1444',
#   '-6',
#   'N',
#   'America/Regina'),
#  (156,
#   '158',
#   'Wiarton',
#   'Wiarton',
#   'Canada',
#   'YVV',
#   'CYVV',
#   '44.745834',
#   '-81.107222',
#   '729',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (157,
#   '159',
#   'Petawawa',
#   'Petawawa',
#   'Canada',
#   'YWA',
#   'CYWA',
#   '45.952221',
#   '-77.319168',
#   '427',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (158,
#   '160',
#   'Winnipeg Intl',
#   'Winnipeg',
#   'Canada',
#   'YWG',
#   'CYWG',
#   '49.910036',
#   '-97.239886',
#   '783',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (159,
#   '161',
#   'Wabush',
#   'Wabush',
#   'Canada',
#   'YWK',
#   'CYWK',
#   '52.921944',
#   '-66.864444',
#   '1808',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (160,
#   '162',
#   'Williams Lake',
#   'Williams Lake',
#   'Canada',
#   'YWL',
#   'CYWL',
#   '52.183056',
#   '-122.054167',
#   '3085',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (161,
#   '163',
#   'Wrigley',
#   'Wrigley',
#   'Canada',
#   'YWY',
#   'CYWY',
#   '63.209444',
#   '-123.436667',
#   '489',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (162,
#   '164',
#   'Canadian Rockies Intl',
#   'Cranbrook',
#   'Canada',
#   'YXC',
#   'CYXC',
#   '49.612222',
#   '-115.781944',
#   '3084',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (163,
#   '165',
#   'Edmonton City Centre',
#   'Edmonton',
#   'Canada',
#   'YXD',
#   'CYXD',
#   '53.5725',
#   '-113.520556',
#   '2200',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (164,
#   '166',
#   'Saskatoon J G Diefenbaker Intl',
#   'Saskatoon',
#   'Canada',
#   'YXE',
#   'CYXE',
#   '52.170834',
#   '-106.699722',
#   '1653',
#   '-6',
#   'N',
#   'America/Regina'),
#  (165,
#   '167',
#   'Medicine Hat',
#   'Medicine Hat',
#   'Canada',
#   'YXH',
#   'CYXH',
#   '50.01889',
#   '-110.720833',
#   '2352',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (166,
#   '168',
#   'Fort St John',
#   'Fort Saint John',
#   'Canada',
#   'YXJ',
#   'CYXJ',
#   '56.238056',
#   '-120.740278',
#   '2280',
#   '-7',
#   'A',
#   'America/Dawson_Creek'),
#  (167,
#   '169',
#   'Sioux Lookout',
#   'Sioux Lookout',
#   'Canada',
#   'YXL',
#   'CYXL',
#   '50.113889',
#   '-91.905278',
#   '1258',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (168,
#   '170',
#   'Pangnirtung',
#   'Pangnirtung',
#   'Canada',
#   'YXP',
#   'CYXP',
#   '66.145',
#   '-65.713611',
#   '75',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (169,
#   '171',
#   'Timiskaming Rgnl',
#   'Earlton',
#   'Canada',
#   'YXR',
#   'CYXR',
#   '47.695',
#   '-79.848889',
#   '798',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (170,
#   '172',
#   'Prince George',
#   'Prince George',
#   'Canada',
#   'YXS',
#   'CYXS',
#   '53.889444',
#   '-122.678889',
#   '2267',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (171,
#   '173',
#   'Terrace',
#   'Terrace',
#   'Canada',
#   'YXT',
#   'CYXT',
#   '54.468508',
#   '-128.576219',
#   '713',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (172,
#   '174',
#   'London',
#   'London',
#   'Canada',
#   'YXU',
#   'CYXU',
#   '43.033056',
#   '-81.151111',
#   '912',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (173,
#   '175',
#   'Abbotsford',
#   'Abbotsford',
#   'Canada',
#   'YXX',
#   'CYXX',
#   '49.025278',
#   '-122.360556',
#   '195',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (174,
#   '176',
#   'Whitehorse Intl',
#   'Whitehorse',
#   'Canada',
#   'YXY',
#   'CYXY',
#   '60.709553',
#   '-135.067269',
#   '2317',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (175,
#   '177',
#   'North Bay',
#   'North Bay',
#   'Canada',
#   'YYB',
#   'CYYB',
#   '46.363611',
#   '-79.422778',
#   '1215',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (176,
#   '178',
#   'Calgary Intl',
#   'Calgary',
#   'Canada',
#   'YYC',
#   'CYYC',
#   '51.113888',
#   '-114.020278',
#   '3557',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (177,
#   '179',
#   'Smithers',
#   'Smithers',
#   'Canada',
#   'YYD',
#   'CYYD',
#   '54.824722',
#   '-127.182778',
#   '1712',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (178,
#   '180',
#   'Fort Nelson',
#   'Fort Nelson',
#   'Canada',
#   'YYE',
#   'CYYE',
#   '58.836389',
#   '-122.596944',
#   '1253',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (179,
#   '181',
#   'Penticton',
#   'Penticton',
#   'Canada',
#   'YYF',
#   'CYYF',
#   '49.463056',
#   '-119.602222',
#   '1129',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (180,
#   '182',
#   'Charlottetown',
#   'Charlottetown',
#   'Canada',
#   'YYG',
#   'CYYG',
#   '46.290001',
#   '-63.121111',
#   '160',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (181,
#   '183',
#   'Taloyoak',
#   'Spence Bay',
#   'Canada',
#   'YYH',
#   'CYYH',
#   '69.546667',
#   '-93.576667',
#   '92',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (182,
#   '184',
#   'Victoria Intl',
#   'Victoria',
#   'Canada',
#   'YYJ',
#   'CYYJ',
#   '48.646944',
#   '-123.425833',
#   '63',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (183,
#   '185',
#   'Lynn Lake',
#   'Lynn Lake',
#   'Canada',
#   'YYL',
#   'CYYL',
#   '56.863888',
#   '-101.07611',
#   '1170',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (184,
#   '186',
#   'Swift Current',
#   'Swift Current',
#   'Canada',
#   'YYN',
#   'CYYN',
#   '50.291944',
#   '-107.690556',
#   '2680',
#   '-6',
#   'N',
#   'America/Regina'),
#  (185,
#   '187',
#   'Churchill',
#   'Churchill',
#   'Canada',
#   'YYQ',
#   'CYYQ',
#   '58.739167',
#   '-94.065',
#   '94',
#   '-6',
#   'A',
#   'America/Winnipeg'),
#  (186,
#   '188',
#   'Goose Bay',
#   'Goose Bay',
#   'Canada',
#   'YYR',
#   'CYYR',
#   '53.319168',
#   '-60.425833',
#   '160',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (187,
#   '189',
#   'St Johns Intl',
#   "St. John's",
#   'Canada',
#   'YYT',
#   'CYYT',
#   '47.61861',
#   '-52.751945',
#   '461',
#   '-3.5',
#   'A',
#   'America/St_Johns'),
#  (188,
#   '190',
#   'Kapuskasing',
#   'Kapuskasing',
#   'Canada',
#   'YYU',
#   'CYYU',
#   '49.413889',
#   '-82.4675',
#   '743',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (189,
#   '191',
#   'Armstrong',
#   'Armstrong',
#   'Canada',
#   'YYW',
#   'CYYW',
#   '50.290279',
#   '-88.909721',
#   '1058',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (190,
#   '192',
#   'Mont Joli',
#   'Mont Joli',
#   'Canada',
#   'YYY',
#   'CYYY',
#   '48.608612',
#   '-68.208056',
#   '172',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (191,
#   '193',
#   'Lester B Pearson Intl',
#   'Toronto',
#   'Canada',
#   'YYZ',
#   'CYYZ',
#   '43.677223',
#   '-79.630556',
#   '569',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (192,
#   '194',
#   'Downsview',
#   'Toronto',
#   'Canada',
#   'YZD',
#   'CYZD',
#   '43.7425',
#   '-79.465556',
#   '652',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (193,
#   '195',
#   'Gore Bay Manitoulin',
#   'Gore Bay',
#   'Canada',
#   'YZE',
#   'CYZE',
#   '45.885277',
#   '-82.567778',
#   '635',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (194,
#   '196',
#   'Yellowknife',
#   'Yellowknife',
#   'Canada',
#   'YZF',
#   'CYZF',
#   '62.462778',
#   '-114.440278',
#   '675',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (195,
#   '197',
#   'Slave Lake',
#   'Slave Lake',
#   'Canada',
#   'YZH',
#   'CYZH',
#   '55.293056',
#   '-114.777222',
#   '1912',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (196,
#   '198',
#   'Sandspit',
#   'Sandspit',
#   'Canada',
#   'YZP',
#   'CYZP',
#   '53.254333',
#   '-131.813833',
#   '21',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (197,
#   '199',
#   'Chris Hadfield',
#   'Sarnia',
#   'Canada',
#   'YZR',
#   'CYZR',
#   '42.999444',
#   '-82.308889',
#   '594',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (198,
#   '200',
#   'Port Hardy',
#   'Port Hardy',
#   'Canada',
#   'YZT',
#   'CYZT',
#   '50.680556',
#   '-127.366667',
#   '71',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (199,
#   '201',
#   'Whitecourt',
#   'Whitecourt',
#   'Canada',
#   'YZU',
#   'CYZU',
#   '54.14389',
#   '-115.786667',
#   '2567',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (200,
#   '202',
#   'Sept Iles',
#   'Sept-iles',
#   'Canada',
#   'YZV',
#   'CYZV',
#   '50.223333',
#   '-66.265556',
#   '180',
#   '-5',
#   'A',
#   'America/Toronto'),
#  (201,
#   '203',
#   'Teslin',
#   'Teslin',
#   'Canada',
#   'YZW',
#   'CYZW',
#   '60.172779',
#   '-132.742778',
#   '2313',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (202,
#   '204',
#   'Greenwood',
#   'Greenwood',
#   'Canada',
#   'YZX',
#   'CYZX',
#   '44.984444',
#   '-64.916944',
#   '92',
#   '-4',
#   'A',
#   'America/Halifax'),
#  (203,
#   '205',
#   'Faro',
#   'Faro',
#   'Canada',
#   'ZFA',
#   'CZFA',
#   '62.2075',
#   '-133.375833',
#   '2351',
#   '-8',
#   'A',
#   'America/Vancouver'),
#  (204,
#   '206',
#   'Fort Mcpherson',
#   'Fort Mcpherson',
#   'Canada',
#   'ZFM',
#   'CZFM',
#   '67.4075',
#   '-134.860556',
#   '116',
#   '-7',
#   'A',
#   'America/Edmonton'),
#  (205,
#   '207',
#   'Blida',
#   'Blida',
#   'Algeria',
#   None,
#   'DAAB',
#   '36.503613',
#   '2.814167',
#   '535',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (206,
#   '208',
#   'Bou Saada',
#   'Bou Saada',
#   'Algeria',
#   None,
#   'DAAD',
#   '35.3325',
#   '4.206389',
#   '1506',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (207,
#   '209',
#   'Soummam',
#   'Bejaja',
#   'Algeria',
#   'BJA',
#   'DAAE',
#   '36.711997',
#   '5.069922',
#   '20',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (208,
#   '210',
#   'Houari Boumediene',
#   'Algier',
#   'Algeria',
#   'ALG',
#   'DAAG',
#   '36.691014',
#   '3.215408',
#   '82',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (209,
#   '211',
#   'Tiska',
#   'Djanet',
#   'Algeria',
#   'DJG',
#   'DAAJ',
#   '24.292767',
#   '9.452444',
#   '3176',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (210,
#   '212',
#   'Boufarik',
#   'Boufarik',
#   'Algeria',
#   'QFD',
#   'DAAK',
#   '36.545834',
#   '2.876111',
#   '335',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (211,
#   '213',
#   'Reggane',
#   'Reggan',
#   'Algeria',
#   None,
#   'DAAN',
#   '26.710103',
#   '0.285647',
#   '955',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (212,
#   '214',
#   'Illizi Takhamalt',
#   'Illizi',
#   'Algeria',
#   'VVZ',
#   'DAAP',
#   '26.723536',
#   '8.622653',
#   '1778',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (213,
#   '215',
#   'Ain Oussera',
#   'Ain Oussera',
#   'Algeria',
#   None,
#   'DAAQ',
#   '35.525414',
#   '2.878714',
#   '2132',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (214,
#   '216',
#   'Tamanrasset',
#   'Tamanrasset',
#   'Algeria',
#   'TMR',
#   'DAAT',
#   '22.811461',
#   '5.451075',
#   '4518',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (215,
#   '217',
#   'Jijel',
#   'Jijel',
#   'Algeria',
#   'GJL',
#   'DAAV',
#   '36.795136',
#   '5.873608',
#   '36',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (216,
#   '218',
#   'Mecheria',
#   'Mecheria',
#   'Algeria',
#   None,
#   'DAAY',
#   '33.535853',
#   '-0.242353',
#   '3855',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (217,
#   '219',
#   'Relizane',
#   'Relizane',
#   'Algeria',
#   None,
#   'DAAZ',
#   '35.752239',
#   '0.626272',
#   '282',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (218,
#   '220',
#   'Annaba',
#   'Annaba',
#   'Algeria',
#   'AAE',
#   'DABB',
#   '36.822225',
#   '7.809167',
#   '16',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (219,
#   '221',
#   'Mohamed Boudiaf Intl',
#   'Constantine',
#   'Algeria',
#   'CZL',
#   'DABC',
#   '36.276028',
#   '6.620386',
#   '2265',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (220,
#   '222',
#   'Cheikh Larbi Tebessi',
#   'Tebessa',
#   'Algeria',
#   'TEE',
#   'DABS',
#   '35.431611',
#   '8.120717',
#   '2661',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (221,
#   '224',
#   'Hassi R Mel',
#   'Tilrempt',
#   'Algeria',
#   'HRM',
#   'DAFH',
#   '32.930431',
#   '3.311542',
#   '2540',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (222,
#   '225',
#   'Bou Chekif',
#   'Tiaret',
#   'Algeria',
#   'TID',
#   'DAOB',
#   '35.341136',
#   '1.463147',
#   '3245',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (223,
#   '226',
#   'Bou Sfer',
#   'Bou Sfer',
#   'Algeria',
#   None,
#   'DAOE',
#   '35.735389',
#   '-0.805389',
#   '187',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (224,
#   '227',
#   'Tindouf',
#   'Tindouf',
#   'Algeria',
#   'TIN',
#   'DAOF',
#   '27.700372',
#   '-8.167103',
#   '1453',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (225,
#   '228',
#   'Ech Cheliff',
#   'Ech-cheliff',
#   'Algeria',
#   'QAS',
#   'DAOI',
#   '36.212658',
#   '1.331775',
#   '463',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (226,
#   '229',
#   'Tafaraoui',
#   'Oran',
#   'Algeria',
#   'TAF',
#   'DAOL',
#   '35.542444',
#   '-0.532278',
#   '367',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (227,
#   '230',
#   'Zenata',
#   'Tlemcen',
#   'Algeria',
#   'TLM',
#   'DAON',
#   '35.016667',
#   '-1.45',
#   '814',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (228,
#   '231',
#   'Es Senia',
#   'Oran',
#   'Algeria',
#   'ORN',
#   'DAOO',
#   '35.623858',
#   '-0.621183',
#   '295',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (229,
#   '232',
#   'Sidi Bel Abbes',
#   'Sidi Bel Abbes',
#   'Algeria',
#   None,
#   'DAOS',
#   '35.171775',
#   '-0.593275',
#   '1614',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (230,
#   '233',
#   'Ghriss',
#   'Ghriss',
#   'Algeria',
#   'MUW',
#   'DAOV',
#   '35.207725',
#   '0.147142',
#   '1686',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (231,
#   '234',
#   'Touat Cheikh Sidi Mohamed Belkebir',
#   'Adrar',
#   'Algeria',
#   'AZR',
#   'DAUA',
#   '27.837589',
#   '-0.186414',
#   '919',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (232,
#   '235',
#   'Biskra',
#   'Biskra',
#   'Algeria',
#   'BSK',
#   'DAUB',
#   '34.793289',
#   '5.738231',
#   '289',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (233,
#   '236',
#   'El Golea',
#   'El Golea',
#   'Algeria',
#   'ELG',
#   'DAUE',
#   '30.571294',
#   '2.859586',
#   '1306',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (234,
#   '237',
#   'Noumerat',
#   'Ghardaia',
#   'Algeria',
#   'GHA',
#   'DAUG',
#   '32.384106',
#   '3.794114',
#   '1512',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (235,
#   '238',
#   'Oued Irara',
#   'Hassi Messaoud',
#   'Algeria',
#   'HME',
#   'DAUH',
#   '31.672972',
#   '6.140444',
#   '463',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (236,
#   '239',
#   'In Salah',
#   'In Salah',
#   'Algeria',
#   'INZ',
#   'DAUI',
#   '27.251022',
#   '2.512017',
#   '896',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (237,
#   '240',
#   'Sidi Mahdi',
#   'Touggourt',
#   'Algeria',
#   'TGR',
#   'DAUK',
#   '33.067803',
#   '6.088672',
#   '279',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (238,
#   '241',
#   'Laghouat',
#   'Laghouat',
#   'Algeria',
#   'LOO',
#   'DAUL',
#   '33.764383',
#   '2.928344',
#   '2510',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (239,
#   '242',
#   'Timimoun',
#   'Timimoun',
#   'Algeria',
#   'TMX',
#   'DAUT',
#   '29.237119',
#   '0.276033',
#   '1027',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (240,
#   '243',
#   'Ouargla',
#   'Ouargla',
#   'Algeria',
#   'OGX',
#   'DAUU',
#   '31.917223',
#   '5.412778',
#   '492',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (241,
#   '244',
#   'In Amenas',
#   'Zarzaitine',
#   'Algeria',
#   'IAM',
#   'DAUZ',
#   '28.05155',
#   '9.642911',
#   '1847',
#   '1',
#   'N',
#   'Africa/Algiers'),
#  (242,
#   '245',
#   'Cadjehoun',
#   'Cotonou',
#   'Benin',
#   'COO',
#   'DBBB',
#   '6.357228',
#   '2.384353',
#   '19',
#   '1',
#   'N',
#   'Africa/Porto-Novo'),
#  (243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (244,
#   '247',
#   'Bobo Dioulasso',
#   'Bobo-dioulasso',
#   'Burkina Faso',
#   'BOY',
#   'DFOO',
#   '11.160056',
#   '-4.330969',
#   '1511',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (245,
#   '248',
#   'Kotoka Intl',
#   'Accra',
#   'Ghana',
#   'ACC',
#   'DGAA',
#   '5.605186',
#   '-0.166786',
#   '205',
#   '0',
#   'N',
#   'Africa/Accra'),
#  (246,
#   '249',
#   'Tamale',
#   'Tamale',
#   'Ghana',
#   'TML',
#   'DGLE',
#   '9.557192',
#   '-0.863214',
#   '553',
#   '0',
#   'N',
#   'Africa/Accra'),
#  (247,
#   '250',
#   'Wa',
#   'Wa',
#   'Ghana',
#   None,
#   'DGLW',
#   '10.082664',
#   '-2.507694',
#   '1060',
#   '0',
#   'N',
#   'Africa/Accra'),
#  (248,
#   '251',
#   'Sunyani',
#   'Sunyani',
#   'Ghana',
#   'NYI',
#   'DGSN',
#   '7.361828',
#   '-2.328756',
#   '1014',
#   '0',
#   'N',
#   'Africa/Accra'),
#  (249,
#   '252',
#   'Takoradi',
#   'Takoradi',
#   'Ghana',
#   'TKD',
#   'DGTK',
#   '4.896056',
#   '-1.774756',
#   '21',
#   '0',
#   'N',
#   'Africa/Accra'),
#  (250,
#   '253',
#   'Abidjan Felix Houphouet Boigny Intl',
#   'Abidjan',
#   "Cote d'Ivoire",
#   'ABJ',
#   'DIAP',
#   '5.261386',
#   '-3.926294',
#   '21',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (251,
#   '254',
#   'Bouake',
#   'Bouake',
#   "Cote d'Ivoire",
#   'BYK',
#   'DIBK',
#   '7.7388',
#   '-5.073667',
#   '1230',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (252,
#   '255',
#   'Daloa',
#   'Daloa',
#   "Cote d'Ivoire",
#   'DJO',
#   'DIDL',
#   '6.792808',
#   '-6.473189',
#   '823',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (253,
#   '256',
#   'Korhogo',
#   'Korhogo',
#   "Cote d'Ivoire",
#   'HGO',
#   'DIKO',
#   '9.387183',
#   '-5.556664',
#   '1214',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (254,
#   '257',
#   'Man',
#   'Man',
#   "Cote d'Ivoire",
#   'MJC',
#   'DIMN',
#   '7.272069',
#   '-7.587364',
#   '1089',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (255,
#   '258',
#   'San Pedro',
#   'San Pedro',
#   "Cote d'Ivoire",
#   'SPY',
#   'DISP',
#   '4.746717',
#   '-6.660817',
#   '26',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (256,
#   '259',
#   'Yamoussoukro',
#   'Yamoussoukro',
#   "Cote d'Ivoire",
#   'ASK',
#   'DIYO',
#   '6.903167',
#   '-5.365581',
#   '699',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (257,
#   '260',
#   'Nnamdi Azikiwe Intl',
#   'Abuja',
#   'Nigeria',
#   'ABV',
#   'DNAA',
#   '9.006792',
#   '7.263172',
#   '1123',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (258,
#   '261',
#   'Akure',
#   'Akure',
#   'Nigeria',
#   'AKR',
#   'DNAK',
#   '7.246739',
#   '5.301008',
#   '1100',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (259,
#   '262',
#   'Benin',
#   'Benin',
#   'Nigeria',
#   'BNI',
#   'DNBE',
#   '6.316981',
#   '5.599503',
#   '258',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (260,
#   '263',
#   'Calabar',
#   'Calabar',
#   'Nigeria',
#   'CBQ',
#   'DNCA',
#   '4.976019',
#   '8.347197',
#   '210',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (261,
#   '264',
#   'Enugu',
#   'Enugu',
#   'Nigeria',
#   'ENU',
#   'DNEN',
#   '6.474272',
#   '7.561961',
#   '466',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (262,
#   '265',
#   'Gusau',
#   'Gusau',
#   'Nigeria',
#   'QUS',
#   'DNGU',
#   '12.171667',
#   '6.696111',
#   '1520',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (263,
#   '266',
#   'Ibadan',
#   'Ibadan',
#   'Nigeria',
#   'IBA',
#   'DNIB',
#   '7.362458',
#   '3.978333',
#   '725',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (264,
#   '267',
#   'Ilorin',
#   'Ilorin',
#   'Nigeria',
#   'ILR',
#   'DNIL',
#   '8.440211',
#   '4.493919',
#   '1126',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (265,
#   '268',
#   'Yakubu Gowon',
#   'Jos',
#   'Nigeria',
#   'JOS',
#   'DNJO',
#   '9.639828',
#   '8.86905',
#   '4232',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (266,
#   '269',
#   'Kaduna',
#   'Kaduna',
#   'Nigeria',
#   'KAD',
#   'DNKA',
#   '10.696025',
#   '7.320114',
#   '2073',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (267,
#   '270',
#   'Mallam Aminu Intl',
#   'Kano',
#   'Nigeria',
#   'KAN',
#   'DNKN',
#   '12.047589',
#   '8.524622',
#   '1562',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (268,
#   '271',
#   'Maiduguri',
#   'Maiduguri',
#   'Nigeria',
#   'MIU',
#   'DNMA',
#   '11.855347',
#   '13.08095',
#   '1099',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (269,
#   '272',
#   'Makurdi',
#   'Makurdi',
#   'Nigeria',
#   'MDI',
#   'DNMK',
#   '7.703883',
#   '8.613939',
#   '371',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (270,
#   '273',
#   'Murtala Muhammed',
#   'Lagos',
#   'Nigeria',
#   'LOS',
#   'DNMM',
#   '6.577369',
#   '3.321156',
#   '135',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (271,
#   '274',
#   'Minna New',
#   'Minna',
#   'Nigeria',
#   'MXJ',
#   'DNMN',
#   '9.652172',
#   '6.462256',
#   '834',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (272,
#   '275',
#   'Port Harcourt Intl',
#   'Port Hartcourt',
#   'Nigeria',
#   'PHC',
#   'DNPO',
#   '5.015494',
#   '6.949594',
#   '87',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (273,
#   '276',
#   'Sadiq Abubakar Iii Intl',
#   'Sokoto',
#   'Nigeria',
#   'SKO',
#   'DNSO',
#   '12.916322',
#   '5.207189',
#   '1010',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (274,
#   '277',
#   'Yola',
#   'Yola',
#   'Nigeria',
#   'YOL',
#   'DNYO',
#   '9.257553',
#   '12.430422',
#   '599',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (275,
#   '278',
#   'Zaria',
#   'Zaria',
#   'Nigeria',
#   'ZAR',
#   'DNZA',
#   '11.130192',
#   '7.685806',
#   '2170',
#   '1',
#   'N',
#   'Africa/Lagos'),
#  (276,
#   '279',
#   'Maradi',
#   'Maradi',
#   'Niger',
#   'MFQ',
#   'DRRM',
#   '13.502531',
#   '7.126753',
#   '1240',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (277,
#   '280',
#   'Diori Hamani',
#   'Niamey',
#   'Niger',
#   'NIM',
#   'DRRN',
#   '13.481547',
#   '2.183614',
#   '732',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (278,
#   '281',
#   'Tahoua',
#   'Tahoua',
#   'Niger',
#   'THZ',
#   'DRRT',
#   '14.875658',
#   '5.265358',
#   '1266',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (279,
#   '282',
#   'Manu Dayak',
#   'Agadez',
#   'Niger',
#   'AJY',
#   'DRZA',
#   '16.965997',
#   '8.000114',
#   '1657',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (280,
#   '283',
#   'Dirkou',
#   'Dirkou',
#   'Niger',
#   None,
#   'DRZD',
#   '18.968703',
#   '12.86865',
#   '1273',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (281,
#   '284',
#   'Diffa',
#   'Diffa',
#   'Niger',
#   None,
#   'DRZF',
#   '13.372894',
#   '12.626686',
#   '994',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (282,
#   '285',
#   'Zinder',
#   'Zinder',
#   'Niger',
#   'ZND',
#   'DRZR',
#   '13.778997',
#   '8.983761',
#   '1516',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (283,
#   '286',
#   'Habib Bourguiba Intl',
#   'Monastir',
#   'Tunisia',
#   'MIR',
#   'DTMB',
#   '35.758056',
#   '10.754722',
#   '9',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (284,
#   '287',
#   'Carthage',
#   'Tunis',
#   'Tunisia',
#   'TUN',
#   'DTTA',
#   '36.851033',
#   '10.227217',
#   '22',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (285,
#   '288',
#   'Sidi Ahmed Air Base',
#   'Bizerte',
#   'Tunisia',
#   None,
#   'DTTB',
#   '37.245447',
#   '9.791453',
#   '20',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (286,
#   '289',
#   'Remada',
#   'Remada',
#   'Tunisia',
#   None,
#   'DTTD',
#   '32.306156',
#   '10.382108',
#   '1004',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (287,
#   '290',
#   'Gafsa',
#   'Gafsa',
#   'Tunisia',
#   'GAF',
#   'DTTF',
#   '34.422022',
#   '8.822503',
#   '1060',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (288,
#   '291',
#   'Gabes',
#   'Gabes',
#   'Tunisia',
#   'GAE',
#   'DTTG',
#   '33.876919',
#   '10.103333',
#   '26',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (289,
#   '292',
#   'Borj El Amri',
#   'Bordj El Amri',
#   'Tunisia',
#   None,
#   'DTTI',
#   '36.721339',
#   '9.943147',
#   '108',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (290,
#   '293',
#   'Zarzis',
#   'Djerba',
#   'Tunisia',
#   'DJE',
#   'DTTJ',
#   '33.875031',
#   '10.775461',
#   '19',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (291,
#   '294',
#   'El Borma',
#   'El Borma',
#   'Tunisia',
#   'EBM',
#   'DTTR',
#   '31.704281',
#   '9.254619',
#   '827',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (292,
#   '295',
#   'Thyna',
#   'Sfax',
#   'Tunisia',
#   'SFA',
#   'DTTX',
#   '34.717953',
#   '10.690972',
#   '85',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (293,
#   '296',
#   'Nefta',
#   'Tozeur',
#   'Tunisia',
#   'TOE',
#   'DTTZ',
#   '33.939722',
#   '8.110556',
#   '287',
#   '1',
#   'E',
#   'Africa/Tunis'),
#  (294,
#   '297',
#   'Niamtougou International',
#   'Niatougou',
#   'Togo',
#   'LRL',
#   'DXNG',
#   '9.767333',
#   '1.09125',
#   '1515',
#   '0',
#   'N',
#   'Africa/Lome'),
#  (295,
#   '298',
#   'Gnassingbe Eyadema Intl',
#   'Lome',
#   'Togo',
#   'LFW',
#   'DXXX',
#   '6.165611',
#   '1.254511',
#   '72',
#   '0',
#   'N',
#   'Africa/Lome'),
#  (296,
#   '299',
#   'Deurne',
#   'Antwerp',
#   'Belgium',
#   'ANR',
#   'EBAW',
#   '51.189444',
#   '4.460278',
#   '39',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (297,
#   '300',
#   'Beauvechain',
#   'Beauvechain',
#   'Belgium',
#   None,
#   'EBBE',
#   '50.75861',
#   '4.768333',
#   '370',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (298,
#   '301',
#   'Kleine Brogel',
#   'Kleine Brogel',
#   'Belgium',
#   None,
#   'EBBL',
#   '51.168333',
#   '5.47',
#   '200',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (299,
#   '302',
#   'Brussels Natl',
#   'Brussels',
#   'Belgium',
#   'BRU',
#   'EBBR',
#   '50.901389',
#   '4.484444',
#   '184',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (300,
#   '303',
#   'Bertrix',
#   'Bertrix',
#   'Belgium',
#   None,
#   'EBBX',
#   '49.891667',
#   '5.223889',
#   '1514',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (301,
#   '304',
#   'Brussels South',
#   'Charleroi',
#   'Belgium',
#   'CRL',
#   'EBCI',
#   '50.459197',
#   '4.453817',
#   '614',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (302,
#   '305',
#   'Chievres Ab',
#   'Chievres',
#   'Belgium',
#   None,
#   'EBCV',
#   '50.575833',
#   '3.831',
#   '193',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (303,
#   '306',
#   'Koksijde',
#   'Koksijde',
#   'Belgium',
#   None,
#   'EBFN',
#   '51.090278',
#   '2.652778',
#   '20',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (304,
#   '307',
#   'Florennes',
#   'Florennes',
#   'Belgium',
#   None,
#   'EBFS',
#   '50.243333',
#   '4.645833',
#   '935',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (305,
#   '308',
#   'Wevelgem',
#   'Kortrijk-vevelgem',
#   'Belgium',
#   'QKT',
#   'EBKT',
#   '50.817222',
#   '3.204722',
#   '64',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (306,
#   '309',
#   'Liege',
#   'Liege',
#   'Belgium',
#   'LGG',
#   'EBLG',
#   '50.637417',
#   '5.443222',
#   '659',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (307,
#   '310',
#   'Oostende',
#   'Ostend',
#   'Belgium',
#   'OST',
#   'EBOS',
#   '51.198889',
#   '2.862222',
#   '13',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (308,
#   '311',
#   'Zutendaal',
#   'Zutendaal',
#   'Belgium',
#   None,
#   'EBSL',
#   '50.9475',
#   '5.590556',
#   '312',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (309,
#   '312',
#   'Sint Truiden',
#   'Sint-truiden',
#   'Belgium',
#   None,
#   'EBST',
#   '50.791944',
#   '5.201667',
#   '246',
#   '1',
#   'E',
#   'Europe/Brussels'),
#  (310,
#   '313',
#   'Saint Hubert Mil',
#   'St.-hubert',
#   'Belgium',
#   None,
# ...
#   'Comoros',
#   'HAH',
#   'FMCH',
#   '-11.533661',
#   '43.27185',
#   '93',
#   '3',
#   'U',
#   'Indian/Comoro'),
#  (897,
#   '913',
#   'Bandaressalam',
#   'Moheli',
#   'Comoros',
#   'NWA',
#   'FMCI',
#   '-12.298108',
#   '43.7664',
#   '46',
#   '3',
#   'U',
#   'Indian/Comoro'),
#  (898,
#   '914',
#   'Ouani',
#   'Anjouan',
#   'Comoros',
#   'AJN',
#   'FMCV',
#   '-12.131667',
#   '44.430279',
#   '62',
#   '3',
#   'U',
#   'Indian/Comoro'),
#  (899,
#   '915',
#   'Dzaoudzi Pamandzi',
#   'Dzaoudzi',
#   'Mayotte',
#   'DZA',
#   'FMCZ',
#   '-12.804722',
#   '45.281113',
#   '23',
#   '3',
#   'U',
#   'Indian/Mayotte'),
#  (900,
#   '916',
#   'St Denis Gillot',
#   'St.-denis',
#   'Reunion',
#   'RUN',
#   'FMEE',
#   '-20.8871',
#   '55.510308',
#   '66',
#   '4',
#   'U',
#   'Indian/Reunion'),
#  (901,
#   '917',
#   'St Pierre Pierrefonds',
#   'St.-pierre',
#   'Reunion',
#   'ZSE',
#   'FMEP',
#   '-21.320039',
#   '55.423581',
#   '56',
#   '4',
#   'U',
#   'Indian/Reunion'),
#  (902,
#   '918',
#   'Ivato',
#   'Antananarivo',
#   'Madagascar',
#   'TNR',
#   'FMMI',
#   '-18.79695',
#   '47.478806',
#   '4198',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (903,
#   '919',
#   'Miandrivazo',
#   'Miandrivazo',
#   'Madagascar',
#   'ZVA',
#   'FMMN',
#   '-19.562778',
#   '45.450832',
#   '203',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (904,
#   '920',
#   'Sainte Marie',
#   'Sainte Marie',
#   'Madagascar',
#   'SMS',
#   'FMMS',
#   '-17.093889',
#   '49.815834',
#   '7',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (905,
#   '921',
#   'Toamasina',
#   'Toamasina',
#   'Madagascar',
#   'TMM',
#   'FMMT',
#   '-18.109517',
#   '49.392536',
#   '22',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (906,
#   '922',
#   'Morondava',
#   'Morondava',
#   'Madagascar',
#   'MOQ',
#   'FMMV',
#   '-20.28475',
#   '44.317614',
#   '30',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (907,
#   '923',
#   'Arrachart',
#   'Antsiranana',
#   'Madagascar',
#   'DIE',
#   'FMNA',
#   '-12.3494',
#   '49.291747',
#   '374',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (908,
#   '924',
#   'Avaratra',
#   'Mananara',
#   'Madagascar',
#   'WMR',
#   'FMNC',
#   '-16.1639',
#   '49.773753',
#   '9',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (909,
#   '925',
#   'Andapa',
#   'Andapa',
#   'Madagascar',
#   'ZWA',
#   'FMND',
#   '-14.651667',
#   '49.620556',
#   '1552',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (910,
#   '926',
#   'Ambilobe',
#   'Ambilobe',
#   'Madagascar',
#   'AMB',
#   'FMNE',
#   '-13.188431',
#   '48.987978',
#   '72',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (911,
#   '927',
#   'Antsirabato',
#   'Antalaha',
#   'Madagascar',
#   'ANM',
#   'FMNH',
#   '-14.999411',
#   '50.320233',
#   '20',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (912,
#   '928',
#   'Analalava',
#   'Analalava',
#   'Madagascar',
#   'HVA',
#   'FMNL',
#   '-14.629694',
#   '47.763783',
#   '345',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (913,
#   '929',
#   'Philibert Tsiranana',
#   'Mahajanga',
#   'Madagascar',
#   'MJN',
#   'FMNM',
#   '-15.667144',
#   '46.351828',
#   '87',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (914,
#   '930',
#   'Fascene',
#   'Nosy-be',
#   'Madagascar',
#   'NOS',
#   'FMNN',
#   '-13.312067',
#   '48.314822',
#   '36',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (915,
#   '931',
#   'Besalampy',
#   'Besalampy',
#   'Madagascar',
#   'BPY',
#   'FMNQ',
#   '-16.741945',
#   '44.481388',
#   '125',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (916,
#   '932',
#   'Maroantsetra',
#   'Maroantsetra',
#   'Madagascar',
#   'WMN',
#   'FMNR',
#   '-15.436666',
#   '49.688332',
#   '13',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (917,
#   '933',
#   'Sambava',
#   'Sambava',
#   'Madagascar',
#   'SVB',
#   'FMNS',
#   '-14.278611',
#   '50.174721',
#   '20',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (918,
#   '934',
#   'Vohimarina',
#   'Vohemar',
#   'Madagascar',
#   'VOH',
#   'FMNV',
#   '-13.375834',
#   '50.002777',
#   '19',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (919,
#   '935',
#   'Ambalabe',
#   'Antsohihy',
#   'Madagascar',
#   'WAI',
#   'FMNW',
#   '-14.89875',
#   '47.993894',
#   '92',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (920,
#   '936',
#   'Ampampamena',
#   'Ampampamena',
#   'Madagascar',
#   None,
#   'FMNZ',
#   '-13.484814',
#   '48.632739',
#   '49',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (921,
#   '937',
#   'Tolagnaro',
#   'Tolagnaro',
#   'Madagascar',
#   'FTU',
#   'FMSD',
#   '-25.038056',
#   '46.956111',
#   '29',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (922,
#   '938',
#   'Fianarantsoa',
#   'Fianarantsoa',
#   'Madagascar',
#   'WFI',
#   'FMSF',
#   '-21.441558',
#   '47.111736',
#   '3658',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (923,
#   '939',
#   'Farafangana',
#   'Farafangana',
#   'Madagascar',
#   'RVA',
#   'FMSG',
#   '-22.805286',
#   '47.820614',
#   '26',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (924,
#   '940',
#   'Manakara',
#   'Manakara',
#   'Madagascar',
#   'WVK',
#   'FMSK',
#   '-22.119722',
#   '48.021667',
#   '33',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (925,
#   '941',
#   'Mananjary',
#   'Mananjary',
#   'Madagascar',
#   'MNJ',
#   'FMSM',
#   '-21.201772',
#   '48.358317',
#   '20',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (926,
#   '942',
#   'Morombe',
#   'Morombe',
#   'Madagascar',
#   'MXM',
#   'FMSR',
#   '-21.753867',
#   '43.375533',
#   '16',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (927,
#   '943',
#   'Toliara',
#   'Toliara',
#   'Madagascar',
#   'TLE',
#   'FMST',
#   '-23.383369',
#   '43.728453',
#   '29',
#   '3',
#   'U',
#   'Indian/Antananarivo'),
#  (928,
#   '944',
#   'Mbanza Congo',
#   "M'banza-congo",
#   'Angola',
#   'SSY',
#   'FNBC',
#   '-6.269897',
#   '14.247025',
#   '1860',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (929,
#   '945',
#   'Benguela',
#   'Benguela',
#   'Angola',
#   'BUG',
#   'FNBG',
#   '-12.609025',
#   '13.403711',
#   '118',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (930,
#   '946',
#   'Cabinda',
#   'Cabinda',
#   'Angola',
#   'CAB',
#   'FNCA',
#   '-5.596992',
#   '12.188353',
#   '66',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (931,
#   '6814',
#   'Culebra Airport',
#   'Culebra Island',
#   'Puerto Rico',
#   'CPX',
#   'TJCP',
#   '18.3127',
#   '-65.3034',
#   '12',
#   '-4',
#   'U',
#   'America/Puerto_Rico'),
#  (932,
#   '948',
#   'Huambo',
#   'Huambo',
#   'Angola',
#   'NOV',
#   'FNHU',
#   '-12.808878',
#   '15.760547',
#   '5587',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (933,
#   '949',
#   'Kuito',
#   'Kuito',
#   'Angola',
#   'SVP',
#   'FNKU',
#   '-12.404633',
#   '16.947414',
#   '5618',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (934,
#   '950',
#   'Lobito',
#   'Lobito',
#   'Angola',
#   None,
#   'FNLB',
#   '-12.371233',
#   '13.536625',
#   '10',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (935,
#   '951',
#   'Luanda 4 De Fevereiro',
#   'Luanda',
#   'Angola',
#   'LAD',
#   'FNLU',
#   '-8.858375',
#   '13.231178',
#   '243',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (936,
#   '952',
#   'Malanje',
#   'Malanje',
#   'Angola',
#   'MEG',
#   'FNMA',
#   '-9.525086',
#   '16.312406',
#   '3868',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (937,
#   '953',
#   'Menongue',
#   'Menongue',
#   'Angola',
#   'SPP',
#   'FNME',
#   '-14.657583',
#   '17.719833',
#   '4469',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (938,
#   '955',
#   'Negage',
#   'Negage',
#   'Angola',
#   'GXG',
#   'FNNG',
#   '-7.754506',
#   '15.287728',
#   '4105',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (939,
#   '956',
#   'Porto Amboim',
#   'Porto Amboim',
#   'Angola',
#   'PBN',
#   'FNPA',
#   '-10.721956',
#   '13.765528',
#   '16',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (940,
#   '957',
#   'Saurimo',
#   'Saurimo',
#   'Angola',
#   'VHC',
#   'FNSA',
#   '-9.689067',
#   '20.431875',
#   '3584',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (941,
#   '958',
#   'Soyo',
#   'Soyo',
#   'Angola',
#   'SZA',
#   'FNSO',
#   '-6.141086',
#   '12.371764',
#   '15',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (942,
#   '959',
#   'Lubango',
#   'Lubango',
#   'Angola',
#   'SDD',
#   'FNUB',
#   '-14.924733',
#   '13.575022',
#   '5778',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (943,
#   '960',
#   'Luena',
#   'Luena',
#   'Angola',
#   'LUO',
#   'FNUE',
#   '-11.768086',
#   '19.897672',
#   '4360',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (944,
#   '961',
#   'Uige',
#   'Uige',
#   'Angola',
#   'UGO',
#   'FNUG',
#   '-7.603067',
#   '15.027822',
#   '2720',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (945,
#   '962',
#   'Xangongo',
#   'Xangongo',
#   'Angola',
#   'XGN',
#   'FNXA',
#   '-16.755417',
#   '14.965344',
#   '3635',
#   '1',
#   'N',
#   'Africa/Luanda'),
#  (946,
#   '963',
#   'Oyem',
#   'Oyem',
#   'Gabon',
#   'OYE',
#   'FOGO',
#   '1.543108',
#   '11.581361',
#   '2158',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (947,
#   '964',
#   'Okondja',
#   'Okondja',
#   'Gabon',
#   'OKN',
#   'FOGQ',
#   '-0.665214',
#   '13.673133',
#   '1325',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (948,
#   '965',
#   'Lambarene',
#   'Lambarene',
#   'Gabon',
#   'LBQ',
#   'FOGR',
#   '-0.704389',
#   '10.245722',
#   '82',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (949,
#   '966',
#   'Bitam',
#   'Bitam',
#   'Gabon',
#   'BMM',
#   'FOOB',
#   '2.075639',
#   '11.493195',
#   '1969',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (950,
#   '967',
#   'Port Gentil',
#   'Port Gentil',
#   'Gabon',
#   'POG',
#   'FOOG',
#   '-0.711739',
#   '8.754383',
#   '13',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (951,
#   '968',
#   'Omboue Hopital',
#   'Omboue Hospial',
#   'Gabon',
#   'OMB',
#   'FOOH',
#   '-1.574733',
#   '9.262694',
#   '33',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (952,
#   '969',
#   'Makokou',
#   'Makokou',
#   'Gabon',
#   'MKU',
#   'FOOK',
#   '0.579211',
#   '12.890908',
#   '1726',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (953,
#   '970',
#   'Leon M Ba',
#   'Libreville',
#   'Gabon',
#   'LBV',
#   'FOOL',
#   '0.4586',
#   '9.412283',
#   '39',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (954,
#   '971',
#   'Mvengue',
#   'Franceville',
#   'Gabon',
#   'MVB',
#   'FOON',
#   '-1.656156',
#   '13.438036',
#   '1450',
#   '1',
#   'N',
#   'Africa/Libreville'),
#  (955,
#   '972',
#   'Principe',
#   'Principe',
#   'Sao Tome and Principe',
#   'PCP',
#   'FPPR',
#   '1.662936',
#   '7.411742',
#   '591',
#   '0',
#   'N',
#   'Africa/Sao_Tome'),
#  (956,
#   '973',
#   'Sao Tome Intl',
#   'Sao Tome',
#   'Sao Tome and Principe',
#   'TMS',
#   'FPST',
#   '0.378175',
#   '6.712153',
#   '33',
#   '0',
#   'N',
#   'Africa/Sao_Tome'),
#  (957,
#   '974',
#   'Beira',
#   'Beira',
#   'Mozambique',
#   'BEW',
#   'FQBR',
#   '-19.796419',
#   '34.907556',
#   '33',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (958,
#   '976',
#   'Inhambane',
#   'Inhambane',
#   'Mozambique',
#   'INH',
#   'FQIN',
#   '-23.876431',
#   '35.408544',
#   '30',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (959,
#   '977',
#   'Lichinga',
#   'Lichinga',
#   'Mozambique',
#   'VXC',
#   'FQLC',
#   '-13.273986',
#   '35.266262',
#   '4505',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (960,
#   '978',
#   'Lumbo',
#   'Lumbo',
#   'Mozambique',
#   None,
#   'FQLU',
#   '-15.033058',
#   '40.671728',
#   '33',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (961,
#   '979',
#   'Maputo',
#   'Maputo',
#   'Mozambique',
#   'MPM',
#   'FQMA',
#   '-25.920836',
#   '32.572606',
#   '145',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (962,
#   '980',
#   'Mueda',
#   'Mueda',
#   'Mozambique',
#   None,
#   'FQMD',
#   '-11.672922',
#   '39.563142',
#   '2789',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (963,
#   '981',
#   'Mocimboa Da Praia',
#   'Mocimboa Da Praia',
#   'Mozambique',
#   'MZB',
#   'FQMP',
#   '-11.361789',
#   '40.354875',
#   '89',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (964,
#   '982',
#   'Marrupa',
#   'Marrupa',
#   'Mozambique',
#   None,
#   'FQMR',
#   '-13.225053',
#   '37.552067',
#   '2480',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (965,
#   '983',
#   'Nacala',
#   'Nacala',
#   'Mozambique',
#   'MNC',
#   'FQNC',
#   '-14.488233',
#   '40.71225',
#   '410',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (966,
#   '984',
#   'Nampula',
#   'Nampula',
#   'Mozambique',
#   'APL',
#   'FQNP',
#   '-15.105611',
#   '39.2818',
#   '1444',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (967,
#   '985',
#   'Pemba',
#   'Pemba',
#   'Mozambique',
#   'POL',
#   'FQPB',
#   '-12.986753',
#   '40.522492',
#   '331',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (968,
#   '986',
#   'Quelimane',
#   'Quelimane',
#   'Mozambique',
#   'UEL',
#   'FQQL',
#   '-17.8555',
#   '36.869106',
#   '36',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (969,
#   '987',
#   'Songo',
#   'Songo',
#   'Mozambique',
#   None,
#   'FQSG',
#   '-15.602694',
#   '32.773189',
#   '2904',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (970,
#   '988',
#   'Tete Chingodzi',
#   'Tete',
#   'Mozambique',
#   'TET',
#   'FQTT',
#   '-16.104817',
#   '33.640181',
#   '525',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (971,
#   '989',
#   'Ulongwe',
#   'Ulongwe',
#   'Mozambique',
#   None,
#   'FQUG',
#   '-14.704617',
#   '34.352369',
#   '4265',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (972,
#   '990',
#   'Vilankulo',
#   'Vilankulu',
#   'Mozambique',
#   'VNX',
#   'FQVL',
#   '-22.018431',
#   '35.313297',
#   '46',
#   '2',
#   'U',
#   'Africa/Maputo'),
#  (973,
#   '991',
#   'Alphonse',
#   'Alphonse',
#   'Seychelles',
#   None,
#   'FSAL',
#   '-7.004783',
#   '52.726247',
#   '10',
#   '4',
#   'U',
#   'Indian/Mahe'),
#  (974,
#   '992',
#   'Desroches',
#   'Desroches',
#   'Seychelles',
#   'DES',
#   'FSDR',
#   '-5.696697',
#   '53.655844',
#   '10',
#   '4',
#   'U',
#   'Indian/Mahe'),
#  (975,
#   '993',
#   'Farquhar',
#   'Farquhar',
#   'Seychelles',
#   None,
#   'FSFA',
#   '-10.109611',
#   '51.176119',
#   '10',
#   '4',
#   'U',
#   'Indian/Mahe'),
#  (976,
#   '994',
#   'Seychelles Intl',
#   'Mahe',
#   'Seychelles',
#   'SEZ',
#   'FSIA',
#   '-4.674342',
#   '55.521839',
#   '10',
#   '4',
#   'U',
#   'Indian/Mahe'),
#  (977,
#   '995',
#   'Praslin',
#   'Praslin',
#   'Seychelles',
#   'PRI',
#   'FSPP',
#   '-4.319292',
#   '55.691417',
#   '10',
#   '4',
#   'U',
#   'Indian/Mahe'),
#  (978,
#   '996',
#   'Coetivy',
#   'Coetivy',
#   'Seychelles',
#   None,
#   'FSSC',
#   '-7.134567',
#   '56.278239',
#   '10',
#   '4',
#   'U',
#   'Indian/Mahe'),
#  (979,
#   '997',
#   'Abeche',
#   'Abeche',
#   'Chad',
#   'AEH',
#   'FTTC',
#   '13.847',
#   '20.844333',
#   '1788',
#   '1',
#   'N',
#   'Africa/Ndjamena'),
#  (980,
#   '998',
#   'Moundou',
#   'Moundou',
#   'Chad',
#   'MQQ',
#   'FTTD',
#   '8.624406',
#   '16.071419',
#   '1407',
#   '1',
#   'N',
#   'Africa/Ndjamena'),
#  (981,
#   '999',
#   'Ndjamena Hassan Djamous',
#   "N'djamena",
#   'Chad',
#   'NDJ',
#   'FTTJ',
#   '12.133689',
#   '15.034019',
#   '968',
#   '1',
#   'N',
#   'Africa/Ndjamena'),
#  (982,
#   '1000',
#   'Faya Largeau',
#   'Faya-largeau',
#   'Chad',
#   'FYT',
#   'FTTY',
#   '17.917053',
#   '19.111078',
#   '771',
#   '1',
#   'N',
#   'Africa/Ndjamena'),
#  (983,
#   '1001',
#   'J M Nkomo Intl',
#   'Bulawayo',
#   'Zimbabwe',
#   'BUQ',
#   'FVBU',
#   '-20.017431',
#   '28.617869',
#   '4359',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (984,
#   '1002',
#   'Charles Prince',
#   'Harare',
#   'Zimbabwe',
#   None,
#   'FVCP',
#   '-17.751561',
#   '30.924706',
#   '4845',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (985,
#   '1003',
#   'Buffalo Range',
#   'Chiredzi',
#   'Zimbabwe',
#   'BFO',
#   'FVCZ',
#   '-21.008083',
#   '31.57855',
#   '1421',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (986,
#   '1004',
#   'Victoria Falls Intl',
#   'Victoria Falls',
#   'Zimbabwe',
#   'VFA',
#   'FVFA',
#   '-18.095881',
#   '25.839006',
#   '3490',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (987,
#   '1005',
#   'Harare Intl',
#   'Harare',
#   'Zimbabwe',
#   'HRE',
#   'FVHA',
#   '-17.931806',
#   '31.092847',
#   '4887',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (988,
#   '1006',
#   'Kariba Intl',
#   'Kariba',
#   'Zimbabwe',
#   'KAB',
#   'FVKB',
#   '-16.519761',
#   '28.884981',
#   '1706',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (989,
#   '1007',
#   'Mutoko',
#   'Mutoko',
#   'Zimbabwe',
#   None,
#   'FVMT',
#   '-17.431917',
#   '32.184502',
#   '3950',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (990,
#   '1008',
#   'Mutare',
#   'Mutare',
#   'Zimbabwe',
#   None,
#   'FVMU',
#   '-18.997499',
#   '32.627224',
#   '3410',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (991,
#   '1009',
#   'Masvingo Intl',
#   'Masvingo',
#   'Zimbabwe',
#   'MVZ',
#   'FVMV',
#   '-20.055333',
#   '30.859111',
#   '3595',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (992,
#   '1010',
#   'Zvishavane',
#   'Zvishavane',
#   'Zimbabwe',
#   None,
#   'FVSH',
#   '-20.289497',
#   '30.088228',
#   '3012',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (993,
#   '1011',
#   'Gweru Thornhill',
#   'Gwert',
#   'Zimbabwe',
#   'GWE',
#   'FVTL',
#   '-19.436394',
#   '29.861911',
#   '4680',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (994,
#   '1012',
#   'Hwange National Park',
#   'Hwange National Park',
#   'Zimbabwe',
#   'WKM',
#   'FVWN',
#   '-18.629872',
#   '27.021042',
#   '3543',
#   '2',
#   'U',
#   'Africa/Harare'),
#  (995,
#   '1013',
#   'Chileka Intl',
#   'Blantyre',
#   'Malawi',
#   'BLZ',
#   'FWCL',
#   '-15.679053',
#   '34.974014',
#   '2555',
#   '2',
#   'U',
#   'Africa/Blantyre'),
#  (996,
#   '1014',
#   'Karonga',
#   'Karonga',
#   'Malawi',
#   'KGJ',
#   'FWKA',
#   '-9.953569',
#   '33.893022',
#   '1765',
#   '2',
#   'U',
#   'Africa/Blantyre'),
#  (997,
#   '1015',
#   'Kasungu',
#   'Kasungu',
#   'Malawi',
#   None,
#   'FWKG',
#   '-13.014631',
#   '33.468597',
#   '3470',
#   '2',
#   'U',
#   'Africa/Blantyre'),
#  (998,
#   '1016',
#   'Kamuzu Intl',
#   'Lilongwe',
#   'Malawi',
#   'LLW',
#   'FWKI',
#   '-13.789378',
#   '33.781',
#   '4035',
#   '2',
#   'U',
#   'Africa/Blantyre'),
#  (999,
#   '1017',
#   'Mzuzu',
#   'Mzuzu',
#   'Malawi',
#   'ZZU',
#   'FWUU',
#   '-11.44475',
#   '34.011776',
#   '4115',
#   '2',
#   'U',
#   'Africa/Blantyre'),
#  ...]

# %% [markdown]
# Looks like we got some data, but it's not clear what each element represents. We can view the column names in the cursor's `description` attribute.

# %%
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %% [markdown]
# ## `pd.read_sql()`

# %% [markdown]
# We can get the data and the column names into a nice, tidy DataFrame using `pd.read_sql()`

# %%
import pandas as pd

airports_df = pd.read_sql(airports_query, con)
airports_df.head()
# Out:
#    index id                        name          city           country code  \
# 0      0  1                      Goroka        Goroka  Papua New Guinea  GKA
# 1      1  2                      Madang        Madang  Papua New Guinea  MAG
# 2      2  3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU
# 3      3  4                      Nadzab        Nadzab  Papua New Guinea  LAE
# 4      4  5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM
#
#    icao   latitude   longitude altitude offset dst              timezone
# 0  AYGA  -6.081689  145.391881     5282     10   U  Pacific/Port_Moresby
# 1  AYMD  -5.207083    145.7887       20     10   U  Pacific/Port_Moresby
# 2  AYMH  -5.826789  144.295861     5388     10   U  Pacific/Port_Moresby
# 3  AYNZ  -6.569828  146.726242      239     10   U  Pacific/Port_Moresby
# 4  AYPY  -9.443383   147.22005      146     10   U  Pacific/Port_Moresby

# %% [markdown]
# ## Explore the Schema

# %% [markdown]
# In SQLite, the schema of our database lives in the `sqlite_master` table. More info [here](https://www.techonthenet.com/sqlite/sys_tables/index.php).

# %%
schema_df = pd.read_sql("""
SELECT *
FROM sqlite_master
""", con)

schema_df

# %%
cursor.execute("""
SELECT *
FROM sqlite_master
""").fetchall()

# %% [markdown]
# It looks like there are three tables in our database: airports, airlines, and routes. Each table also has an **index**, which is used to optimize queries for large databases.
#
# The column names and datatypes for each table are defined in the schema in the `sql` column.

# %%
# Airports table info

print(schema_df['sql'].iloc[0])

# %% [markdown]
# ## Exercise

# %% [markdown]
# Get the columns and datatypes for the airlines table. You can do this with either `pd.read_sql()` or the schema table.

# %% [markdown]
# <details>
#     <summary><b><u>Click Here for Answer Code</u></b></summary>
#
# ```python
# pd.read_sql("""
#
# SELECT *
# FROM airlines
#
# """, con).info()
# ```
#
# OR
#
# ```python
# print(schema_df['sql'].iloc[2])
# ```
# </details>

# %%
# Your work here

# %% [markdown]
# # Writing SQL Queries

# %% [markdown]
# In this section we will build SQL queries using the SELECT statement, showing off a bunch of different clauses and options available.

# %% [markdown]
# ## SELECT Statement

# %% [markdown]
# SELECT statements can have multiple **clauses**, which must be included in a specific order (more info [here](https://sqlite.org/lang_select.html)). Only SELECT and FROM are required.

# %% [markdown]
# Let's explore the following clauses and structure:
#
# ```sql
# SELECT columns
# FROM table
# WHERE condition
# ORDER BY columns
# LIMIT number
# ```

# %% [markdown]
# ## SELECT: Picking Columns

# %% [markdown]
# Add the names of the columns that you want after the word `SELECT`, or use `*` to get all columns.

# %%
pd.read_sql("""

SELECT city
    , country
FROM airports

""", con)

# %% [markdown]
# ### `DISTINCT`

# %% [markdown]
# Use `DISTINCT` to drop duplicates.

# %%
pd.read_sql("""

SELECT DISTINCT city
            , country
FROM airports

""", con)

# %% [markdown]
# ### `AS`

# %% [markdown]
# Use `AS` to rename columns.

# %%
pd.read_sql("""

SELECT city AS "Airport City", 
       country AS "Airport Country"
FROM airports

""", con)

# %% [markdown]
# ### Functions

# %% [markdown]
# There are dozens of functions that you can use in SELECT statements to modify results - you can see some examples [here](https://sqlite.org/lang_corefunc.html).

# %%
pd.read_sql("""

SELECT UPPER(name) AS "AIRPORT NAMES IN CAPS",
       LENGTH(name) AS "Airport Name Length"
       
FROM airports

""", con)

# %% [markdown]
# #### Aggregation

# %% [markdown]
# Some functions will aggregate your data and return a table with one row.

# %%
pd.read_sql("""

SELECT COUNT() AS "Number of Airports"
FROM airports

""", con)

# %% [markdown]
# #### Datatype Compatibility

# %% [markdown]
# Make sure that your column is the right datatype for the function to avoid unexpected results.

# %%
pd.read_sql("""

SELECT name AS "Airport Name", 
       MAX(altitude) AS "Altitude (ft)"
       
FROM airports

""", con)

# %% [markdown]
# #### `CAST()`

# %% [markdown]
# You could fix this using the `CAST()` function.

# %%
pd.read_sql("""

SELECT name AS "Airport Name", 
       MAX(CAST(altitude as int)) AS "Altitude (ft)"

FROM airports

""", con)

# %% [markdown]
# ### Exercise

# %% [markdown]
# Which country has the northern-most airport?
#
# > _Hint: Look for the highest latitude_

# %% [markdown]
# <details>
#     <summary><b><u>Click Here for Answer Code</u></b></summary>
#
# ```python
# pd.read_sql("""
#
# SELECT country AS "Country",
#        MAX(CAST(latitude as int)) AS "Latitude"
#
# FROM airports
#
# """, con)
# ```
# </details>

# %%
# Your work here

# %% [markdown]
# ## FROM: Picking Tables

# %% [markdown]
# The `FROM` clause specifies the tables you get data from. You can use aliases here with `AS` - this will be useful for more complex queries involving multiple tables.

# %%
pd.read_sql("""

SELECT ap.name AS "Airport Name" 
       , MAX(CAST(ap.altitude AS int)) AS "Altitude (ft)"
       
FROM airports AS ap

""", con)

# %% [markdown]
# ## WHERE: Picking Rows

# %% [markdown]
# The `WHERE` clause filters results from your query. This uses conditional logic and operators similar to Python's - you can find more [here](https://sqlite.org/lang_expr.html).

# %%
pd.read_sql("""

SELECT name AS "Airport Name" 
       , CAST(latitude AS int) AS "Airport Latitude"
       , CAST(altitude AS int) AS "Altitude (ft)"
       
FROM airports

WHERE "Altitude (ft)" >= 10000 
      AND "Airport Latitude" BETWEEN 20 AND 50

""", con)

# %% [markdown]
# ### `IS`

# %% [markdown]
# The `IS` operator is useful when working with `NULL` values - other operators will not work as expected.

# %%
pd.read_sql("""

SELECT name AS "Airport Name"
       , code AS "Airport Code"
       
FROM airports

WHERE code IS NOT NULL

""", con)

# %% [markdown]
# ## ORDER BY: Sorting Results

# %% [markdown]
# Use `ORDER BY` to identify the column(s) you want to sort on. Specify `ASC` for ascending order, `DESC` for descending order.

# %%
pd.read_sql("""

SELECT name AS "Airport Name" 
       , CAST(latitude AS int) AS "Airport Latitude"
       , CAST(altitude AS int) AS "Altitude (ft)"
       
FROM airports

WHERE CAST(altitude AS int) >= 10000

ORDER BY CAST(latitude AS int) DESC, 
         CAST(altitude AS int) DESC 
         
""", con)

# %% [markdown]
# ## LIMIT: Number of Results

# %% [markdown]
# Specify the maximum number of results you want

# %%
pd.read_sql("""

SELECT name AS "Airport Name", 
       CAST(latitude AS int) AS "Airport Latitude",
       CAST(altitude AS int) AS "Altitude (ft)"
       
FROM airports

WHERE CAST(altitude AS int) >= 10000

ORDER BY CAST(latitude AS int) DESC,
         CAST(altitude AS int) DESC 
         
LIMIT 10

""", con)

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Country List

# %% [markdown]
# Create a list of countries with airports and order them alphabetically A-Z.
#
# > _Hint: You will need to remove duplicates._

# %% [markdown]
# <details>
#     <summary><b><u>Click Here for Answer Code</u></b></summary>
#
# ```python
# pd.read_sql("""
#
# SELECT DISTINCT country
# FROM airports
# ORDER BY country ASC
#
# """, con)
# ```
# </details>

# %%
# Your work here

# %% [markdown]
# ## Southern Airports

# %% [markdown]
# Get the name, country and latitude of the 10 southern-most airports.
#
# > _Hint: Look for the smallest latitude._

# %% [markdown]
# <details>
#     <summary><b><u>Click Here for Answer Code</u></b></summary>
#
# ```python
# pd.read_sql("""
#
# SELECT name, country, CAST(latitude AS int) AS "Airport Latitude"
# FROM airports
# ORDER BY "Airport Latitude" ASC
# LIMIT 10
#
# """, con)
# ```
# </details>

# %%
# Your work here

# %% [markdown]
# ## Active UK Airlines

# %% [markdown]
# Create a list of active airlines in the United Kingdom from the airlines table.
#
# > _Hint: You will need to explore the airlines table to figure out how to do this._

# %% [markdown]
# <details>
#     <summary><b><u>Click Here for Answer Code</u></b></summary>
#
# ```python
# pd.read_sql("""
#
# SELECT name
# FROM airlines
# WHERE active='Y'
# AND country='United Kingdom'
#
# """, con)
# ```
# </details>

# %%
# Your work here

# %% [markdown]
# ## Explore Routes

# %% [markdown]
# Get the column names from the routes table and inspect some raw data. Which columns might be keys that connect this table to the other two tables?

# %% [markdown]
# <details>
#     <summary><b><u>Click Here for Answer Code</u></b></summary>
#
# ```python
# pd.read_sql("""
#
# SELECT *
# FROM routes
# LIMIT 5
#
# """, con)
# ```
# > The airline_id is a foreign key to the airlines table, the source_id and dest_id columns are foreign keys to the airports table
#
# </details>

# %%
# Your work here

# %% [markdown]
# # Level Up: `CASE`

# %% [markdown]
# Use `CASE` to create new columns using conditional logic.

# %%
pd.read_sql("""

SELECT name AS "Airport Name", 
       CAST(altitude AS int) AS "Altitude (ft)",
       CASE 
            WHEN CAST(altitude AS int) > 1000 THEN "High"
            WHEN CAST(altitude AS int) < 100 THEN "Low"
            ELSE "Moderate"
       END AS "Altitude Category"
       
FROM airports
         
LIMIT 20

""", con)

# %% [markdown]
# # Level Up: SQL Joins

# %% [markdown]
# SQL joins can be used to both **add** data to a table and **remove** data from a table.

# %% [markdown]
# ![venn](img/venn.png)

# %% [markdown]
# How are these different joins possible?
#
# Notice that I choose a column from each table "on" which to effect the join. This is the means by which I pair up the records from one table with the records of another.
#
# Look back up at the sample diagram under "What is a Relational Database?". We might use the "student_id" column to match up names in the names table with grades in the grades table. But what if there are values in one table's version of "student_id" that don't appear in the other table's version? In that case we need to let the software know whether or not we want to have *all* of the records, regardless of whether they have corresponding entries in all the tables we are joining. This makes for the variety depicted above.
#
# - If I select records from "A INNER JOIN B", then a record will be displayed *only if it exists in both tables*.
#
# - If I select records from "A LEFT JOIN B", then *all relevant records from A will be displayed*, regardless of whether they have representation in B. Records from B with no representation in A will *not* be displayed.

# %%
pd.read_sql("""

    SELECT p.name
        , l.name
        , p.country
    FROM airports p
    LEFT JOIN airlines l
        ON p.country=l.country
    ORDER BY l.name
    LIMIT 5
    
""", con)

# %%
pd.read_sql("""
    
    SELECT p.name
        , l.name
        , p.country
    FROM airports p
    INNER JOIN airlines l
        ON p.country=l.country
    ORDER BY l.name
    LIMIT 5
    
""", con)
